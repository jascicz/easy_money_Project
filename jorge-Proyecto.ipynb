# %% [markdown]
# # Lectura de ficheros easyMoney

# %% [markdown]
# ## import Libraries

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option("display.max_columns", 500)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ## import Files

# %%
#file_dir = 'D:/Anaconda/Nuclio/TFM/data/'

# %%
#p_file = 'products_df.csv'
#c_file = 'commercial_activity_df.csv'
#s_file = 'sociodemographic_df.csv'

# %%
#pdf = pd.read_csv(file_dir + p_file)
#cdf = pd.read_csv(file_dir + c_file)
#sdf = pd.read_csv(file_dir + s_file)

# %%
#pdf = pd.read_csv(file_dir + p_file)
#cdf = pd.read_csv(file_dir + c_file)
#sdf = pd.read_csv(file_dir + s_file)

# %%
#pdf.shape, cdf.shape, sdf.shape

# %%
#pdf.columns, cdf.columns, sdf.columns

# %%
#pdf.drop('Unnamed: 0', axis=1, inplace=True)

#sdf.drop('Unnamed: 0',axis=1, inplace=True)

#cdf.drop('Unnamed: 0',axis=1, inplace=True)

# %%
#pdf.columns, cdf.columns, sdf.columns

# %%
#df_= pd.merge(pdf,cdf, how="inner" ,on=['pk_cid','pk_partition'])

# %%
#df=pd.merge(df_,sdf, how="inner",on=['pk_cid','pk_partition'])

# %%
#df.to_parquet("D:/Anaconda/Nuclio/TFM/data/dfcompleto.parquet")

# %%
df = pd.read_parquet("D:/Anaconda/Nuclio/TFM/data/dfcompleto.parquet")

# %%
df.head(4)
# Out:
#     pk_cid pk_partition  short_term_deposit  loans  mortgage  funds  \
# 0  1375586   2018-01-28                   0      0         0      0
# 1  1050611   2018-01-28                   0      0         0      0
# 2  1050612   2018-01-28                   0      0         0      0
# 3  1050613   2018-01-28                   1      0         0      0
#
#    securities  long_term_deposit  em_account_pp  credit_card  payroll  \
# 0           0                  0              0            0     0.00
# 1           0                  0              0            0     0.00
# 2           0                  0              0            0     0.00
# 3           0                  0              0            0     0.00
#
#    pension_plan  payroll_account  emc_account  debit_card  em_account_p  \
# 0          0.00                0            0           0             0
# 1          0.00                0            0           0             0
# 2          0.00                0            0           0             0
# 3          0.00                0            0           0             0
#
#    em_acount  entry_date entry_channel  active_customer             segment  \
# 0          1  2018-01-12           KHL             1.00   02 - PARTICULARES
# 1          1  2015-08-10           KHE             0.00  03 - UNIVERSITARIO
# 2          1  2015-08-10           KHE             0.00  03 - UNIVERSITARIO
# 3          0  2015-08-10           KHD             0.00  03 - UNIVERSITARIO
#
#   country_id  region_code gender  age deceased    salary
# 0         ES        29.00      H   35        N  87218.10
# 1         ES        13.00      V   23        N  35548.74
# 2         ES        13.00      V   23        N 122179.11
# 3         ES        50.00      H   22        N 119775.54

# %%
df.describe().T
# Out:
#                         count       mean       std      min        25%  \
# pk_cid             5962924.00 1234929.80 162302.04 15891.00 1112532.00
# short_term_deposit 5962924.00       0.00      0.05     0.00       0.00
# loans              5962924.00       0.00      0.01     0.00       0.00
# mortgage           5962924.00       0.00      0.01     0.00       0.00
# funds              5962924.00       0.00      0.06     0.00       0.00
# securities         5962924.00       0.00      0.06     0.00       0.00
# long_term_deposit  5962924.00       0.02      0.13     0.00       0.00
# em_account_pp      5962924.00       0.00      0.00     0.00       0.00
# credit_card        5962924.00       0.01      0.11     0.00       0.00
# payroll            5962863.00       0.03      0.18     0.00       0.00
# pension_plan       5962863.00       0.04      0.19     0.00       0.00
# payroll_account    5962924.00       0.06      0.23     0.00       0.00
# emc_account        5962924.00       0.05      0.23     0.00       0.00
# debit_card         5962924.00       0.09      0.29     0.00       0.00
# em_account_p       5962924.00       0.00      0.00     0.00       0.00
# em_acount          5962924.00       0.73      0.44     0.00       0.00
# active_customer    5962924.00       0.40      0.49     0.00       0.00
# region_code        5960660.00      25.81     13.60     1.00      13.00
# age                5962924.00      29.76     11.98     2.00      22.00
# salary             4450821.00  115816.72 199551.89  1202.73   61500.63
#
#                           50%        75%         max
# pk_cid             1231097.00 1352339.00  1553689.00
# short_term_deposit       0.00       0.00        1.00
# loans                    0.00       0.00        1.00
# mortgage                 0.00       0.00        1.00
# funds                    0.00       0.00        1.00
# securities               0.00       0.00        1.00
# long_term_deposit        0.00       0.00        1.00
# em_account_pp            0.00       0.00        0.00
# credit_card              0.00       0.00        1.00
# payroll                  0.00       0.00        1.00
# pension_plan             0.00       0.00        1.00
# payroll_account          0.00       0.00        1.00
# emc_account              0.00       0.00        1.00
# debit_card               0.00       0.00        1.00
# em_account_p             0.00       0.00        1.00
# em_acount                1.00       1.00        1.00
# active_customer          0.00       1.00        1.00
# region_code             28.00      36.00       52.00
# age                     25.00      34.00      105.00
# salary               88654.65  131669.91 28894395.51

# %%
df.describe(include="object").T
# Out:
#                  count unique                 top     freq
# pk_partition   5962924     17          2019-05-28   442995
# entry_date     5962924   1499          2017-07-28    57389
# entry_channel  5829891     68                 KHE  3113947
# segment        5828980      3  03 - UNIVERSITARIO  3900166
# country_id     5962924     41                  ES  5960672
# gender         5962899      2                   H  3087502
# deceased       5962924      2                   N  5961849

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962924 entries, 0 to 5962923
# Data columns (total 27 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   pk_cid              int64
#  1   pk_partition        object
#  2   short_term_deposit  int64
#  3   loans               int64
#  4   mortgage            int64
#  5   funds               int64
#  6   securities          int64
#  7   long_term_deposit   int64
#  8   em_account_pp       int64
#  9   credit_card         int64
#  10  payroll             float64
#  11  pension_plan        float64
#  12  payroll_account     int64
#  13  emc_account         int64
#  14  debit_card          int64
#  15  em_account_p        int64
#  16  em_acount           int64
#  17  entry_date          object
#  18  entry_channel       object
#  19  active_customer     float64
#  20  segment             object
#  21  country_id          object
#  22  region_code         float64
#  23  gender              object
#  24  age                 int64
#  25  deceased            object
#  26  salary              float64
# dtypes: float64(5), int64(15), object(7)
# memory usage: 1.2+ GB

# %%
df.isna().sum()
# Out:
# pk_cid                      0
# pk_partition                0
# short_term_deposit          0
# loans                       0
# mortgage                    0
# funds                       0
# securities                  0
# long_term_deposit           0
# em_account_pp               0
# credit_card                 0
# payroll                    61
# pension_plan               61
# payroll_account             0
# emc_account                 0
# debit_card                  0
# em_account_p                0
# em_acount                   0
# entry_date                  0
# entry_channel          133033
# active_customer             0
# segment                133944
# country_id                  0
# region_code              2264
# gender                     25
# age                         0
# deceased                    0
# salary                1512103
# dtype: int64

# %% [markdown]
# # Corrección y Cambio a fechas

# %%
pd.to_datetime(df["pk_partition"])
# Out:
# 0         2018-01-28
# 1         2018-01-28
# 2         2018-01-28
# 3         2018-01-28
# 4         2018-01-28
#              ...
# 5962919   2019-05-28
# 5962920   2019-05-28
# 5962921   2019-05-28
# 5962922   2019-05-28
# 5962923   2019-05-28
# Name: pk_partition, Length: 5962924, dtype: datetime64[ns]

# %%
#pd.to_datetime(df["entry_date"])
pd.to_datetime(df["entry_date"],errors="coerce").sort_values().tail(20)
# Out:
# 5839086   NaT
# 5839087   NaT
# 5839088   NaT
# 5839089   NaT
# 5839090   NaT
# 5839102   NaT
# 5839103   NaT
# 5839104   NaT
# 5839105   NaT
# 5839106   NaT
# 5839107   NaT
# 5839108   NaT
# 5839109   NaT
# 5839110   NaT
# 5839111   NaT
# 5839112   NaT
# 5839113   NaT
# 5839114   NaT
# 5839115   NaT
# 5839117   NaT
# Name: entry_date, dtype: datetime64[ns]

# %%
df.loc[5839086,"entry_date"]
# Out:
# '2015-02-29'

# %%
df.loc[(df['entry_date']=='2015-02-29'),'entry_date']='2015-02-28'

# %%
pd.to_datetime(df["entry_date"],errors="coerce").sort_values().tail(20)
# Out:
# 5677027   NaT
# 5677028   NaT
# 5677029   NaT
# 5677030   NaT
# 5677031   NaT
# 5677032   NaT
# 5677033   NaT
# 5677034   NaT
# 5677035   NaT
# 5677036   NaT
# 5677037   NaT
# 5677038   NaT
# 5677039   NaT
# 5689422   NaT
# 5691810   NaT
# 5693811   NaT
# 5702922   NaT
# 5712793   NaT
# 5730916   NaT
# 5730917   NaT
# Name: entry_date, dtype: datetime64[ns]

# %%
df.loc[5677027,"entry_date"]
# Out:
# '2019-02-29'

# %%
df.loc[(df['entry_date']=='2019-02-29'),'entry_date']='2019-02-28'

# %%
pd.to_datetime(df["entry_date"])
# Out:
# 0         2018-01-12
# 1         2015-08-10
# 2         2015-08-10
# 3         2015-08-10
# 4         2015-08-10
#              ...
# 5962919   2016-08-14
# 5962920   2016-08-14
# 5962921   2016-08-14
# 5962922   2016-08-14
# 5962923   2019-05-13
# Name: entry_date, Length: 5962924, dtype: datetime64[ns]

# %%
df["pk_partition"] = pd.to_datetime(df["pk_partition"])
df["entry_date"] = pd.to_datetime(df["entry_date"])

# %% [markdown]
# # Relleno de NaN payroll y pension_plan con .ffill rellena con lo que hay en la ultima fila

# %%
df.sort_values(by=['pk_cid', 'pk_partition', 'entry_date'], inplace=True)

# %%
df.head()
# Out:
#          pk_cid pk_partition  short_term_deposit  loans  mortgage  funds  \
# 1479563   15891   2018-07-28                   0      0         0      0
# 2168122   15891   2018-08-28                   0      0         0      0
# 2962973   16063   2018-11-28                   0      0         0      0
# 3628236   16063   2018-12-28                   0      0         0      0
# 4028169   16063   2019-01-28                   0      0         0      0
#
#          securities  long_term_deposit  em_account_pp  credit_card  payroll  \
# 1479563           0                  0              0            0     0.00
# 2168122           0                  0              0            0     0.00
# 2962973           0                  0              0            0     0.00
# 3628236           0                  0              0            0     0.00
# 4028169           0                  0              0            0     0.00
#
#          pension_plan  payroll_account  emc_account  debit_card  em_account_p  \
# 1479563          0.00                0            0           0             0
# 2168122          0.00                0            0           0             0
# 2962973          0.00                0            0           0             0
# 3628236          0.00                0            0           0             0
# 4028169          0.00                0            0           0             0
#
#          em_acount entry_date entry_channel  active_customer  \
# 1479563          1 2018-07-28           KAT             1.00
# 2168122          0 2018-07-28           KAT             0.00
# 2962973          0 2018-11-19           KAT             1.00
# 3628236          0 2018-11-19           KAT             1.00
# 4028169          0 2018-11-19           KAT             1.00
#
#                    segment country_id  region_code gender  age deceased  \
# 1479563               None         ES        28.00      H   59        N
# 2168122  02 - PARTICULARES         ES        28.00      H   59        N
# 2962973               None         ES        28.00      H   62        N
# 3628236  02 - PARTICULARES         ES        28.00      H   62        N
# 4028169  02 - PARTICULARES         ES        28.00      H   62        N
#
#          salary
# 1479563     NaN
# 2168122     NaN
# 2962973     NaN
# 3628236     NaN
# 4028169     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5962924 entries, 1479563 to 5679912
# Data columns (total 27 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   pk_cid              int64
#  1   pk_partition        datetime64[ns]
#  2   short_term_deposit  int64
#  3   loans               int64
#  4   mortgage            int64
#  5   funds               int64
#  6   securities          int64
#  7   long_term_deposit   int64
#  8   em_account_pp       int64
#  9   credit_card         int64
#  10  payroll             float64
#  11  pension_plan        float64
#  12  payroll_account     int64
#  13  emc_account         int64
#  14  debit_card          int64
#  15  em_account_p        int64
#  16  em_acount           int64
#  17  entry_date          datetime64[ns]
#  18  entry_channel       object
#  19  active_customer     float64
#  20  segment             object
#  21  country_id          object
#  22  region_code         float64
#  23  gender              object
#  24  age                 int64
#  25  deceased            object
#  26  salary              float64
# dtypes: datetime64[ns](2), float64(5), int64(15), object(5)
# memory usage: 1.2+ GB

# %%
df.isna().sum()
# Out:
# pk_cid                      0
# pk_partition                0
# short_term_deposit          0
# loans                       0
# mortgage                    0
# funds                       0
# securities                  0
# long_term_deposit           0
# em_account_pp               0
# credit_card                 0
# payroll                    61
# pension_plan               61
# payroll_account             0
# emc_account                 0
# debit_card                  0
# em_account_p                0
# em_acount                   0
# entry_date                  0
# entry_channel          133033
# active_customer             0
# segment                133944
# country_id                  0
# region_code              2264
# gender                     25
# age                         0
# deceased                    0
# salary                1512103
# dtype: int64

# %%
df[df['payroll'].isna()].sort_values(by=['pk_cid','pk_partition','entry_date'])
# Out:
#           pk_cid pk_partition  short_term_deposit  loans  mortgage  funds  \
# 20679    1023793   2018-01-28                   0      0         0      0
# 444921   1040205   2018-02-28                   0      0         0      0
# 452290   1042950   2018-02-28                   0      0         0      0
# 662834   1083617   2018-03-28                   0      0         0      0
# 45769    1097831   2018-01-28                   0      0         0      0
# ...          ...          ...                 ...    ...       ...    ...
# 1107155  1377542   2018-05-28                   0      0         0      0
# 831368   1379131   2018-04-28                   0      0         0      0
# 584051   1387288   2018-03-28                   0      0         0      0
# 583793   1389351   2018-03-28                   0      0         0      0
# 1118942  1395511   2018-05-28                   0      0         0      0
#
#          securities  long_term_deposit  em_account_pp  credit_card  payroll  \
# 20679             0                  0              0            0      NaN
# 444921            0                  0              0            0      NaN
# 452290            0                  0              0            0      NaN
# 662834            0                  0              0            0      NaN
# 45769             0                  0              0            0      NaN
# ...             ...                ...            ...          ...      ...
# 1107155           0                  0              0            0      NaN
# 831368            0                  0              0            0      NaN
# 584051            0                  0              0            0      NaN
# 583793            0                  0              0            0      NaN
# 1118942           0                  0              0            0      NaN
#
#          pension_plan  payroll_account  emc_account  debit_card  em_account_p  \
# 20679             NaN                0            0           0             0
# 444921            NaN                0            0           0             0
# 452290            NaN                0            0           0             0
# 662834            NaN                0            0           0             0
# 45769             NaN                0            0           0             0
# ...               ...              ...          ...         ...           ...
# 1107155           NaN                0            0           0             0
# 831368            NaN                0            0           0             0
# 584051            NaN                0            0           0             0
# 583793            NaN                0            0           0             0
# 1118942           NaN                0            0           0             0
#
#          em_acount entry_date entry_channel  active_customer  \
# 20679            0 2015-07-17           KHK             0.00
# 444921           0 2015-08-02          None             1.00
# 452290           0 2015-08-03           KHM             0.00
# 662834           0 2015-10-18          None             1.00
# 45769            0 2015-11-08           KHL             0.00
# ...            ...        ...           ...              ...
# 1107155          0 2018-01-21          None             0.00
# 831368           0 2018-01-30           KFA             0.00
# 584051           0 2018-03-12           KHK             1.00
# 583793           0 2018-03-25           RED             1.00
# 1118942          0 2018-05-05          None             0.00
#
#                     segment country_id  region_code gender  age deceased  \
# 20679    03 - UNIVERSITARIO         ES        45.00      V   23        N
# 444921                 None         ES        41.00      V   25        N
# 452290   03 - UNIVERSITARIO         ES        37.00      V   30        N
# 662834                 None         ES        46.00      V   24        N
# 45769     02 - PARTICULARES         ES        24.00      H   34        N
# ...                     ...        ...          ...    ...  ...      ...
# 1107155                None         ES        41.00      V   39        N
# 831368    02 - PARTICULARES         ES        28.00      V   75        N
# 584051    02 - PARTICULARES         ES        46.00      V   37        N
# 583793    02 - PARTICULARES         ES        46.00      V   61        N
# 1118942                None         ES        28.00      H   32        N
#
#            salary
# 20679    93426.06
# 444921  122290.17
# 452290  135663.84
# 662834        NaN
# 45769    71026.71
# ...           ...
# 1107155  85476.99
# 831368  105874.23
# 584051   30365.94
# 583793   65386.32
# 1118942  99731.22
#
# [61 rows x 27 columns]

# %%
df[df["pk_cid"] == 1389351]
# Out:
#           pk_cid pk_partition  short_term_deposit  loans  mortgage  funds  \
# 583793   1389351   2018-03-28                   0      0         0      0
# 833341   1389351   2018-04-28                   1      0         0      0
# 1115696  1389351   2018-05-28                   1      0         0      0
# 1374911  1389351   2018-06-28                   1      0         0      0
# 1778863  1389351   2018-07-28                   0      0         0      0
# 1992315  1389351   2018-08-28                   0      0         0      0
# 2452353  1389351   2018-09-28                   0      0         0      0
# 2763724  1389351   2018-10-28                   0      0         0      0
# 3200875  1389351   2018-11-28                   0      0         0      0
# 3767825  1389351   2018-12-28                   0      0         0      0
# 3948005  1389351   2019-01-28                   0      0         0      0
# 3200875          0 2018-03-25           RED             1.00
# 3767825          0 2018-03-25           RED             1.00
# 3948005          0 2018-03-25           RED             1.00
# 4443971          0 2018-03-25           RED             1.00
# 4838742          0 2018-03-25           RED             1.00
# 5290188          0 2018-03-25           RED             1.00
# 5578482          0 2018-03-25           RED             1.00
#
#                    segment country_id  region_code gender  age deceased  \
# 583793   02 - PARTICULARES         ES        46.00      V   61        N
# 833341   02 - PARTICULARES         ES        46.00      V   61        N
# 1115696  02 - PARTICULARES         ES        46.00      V   61        N
# 1374911  02 - PARTICULARES         ES        46.00      V   61        N
# 1778863  02 - PARTICULARES         ES        46.00      V   61        N
# 1992315  02 - PARTICULARES         ES        46.00      V   61        N
# 2452353  02 - PARTICULARES         ES        46.00      V   61        N
# 2763724  02 - PARTICULARES         ES        46.00      V   61        N
# 3200875  02 - PARTICULARES         ES        46.00      V   61        N
# 3767825  02 - PARTICULARES         ES        46.00      V   61        N
# 3948005  02 - PARTICULARES         ES        46.00      V   61        N
# 4443971  02 - PARTICULARES         ES        46.00      V   61        N
# 4838742  02 - PARTICULARES         ES        46.00      V   62        N
# 5290188  02 - PARTICULARES         ES        46.00      V   62        N
# 5578482           01 - TOP         ES        46.00      V   62        N
#
#           salary
# 583793  65386.32
# 833341  65386.32
# 1115696 65386.32
# 1374911 65386.32
# 1778863 65386.32
# 1992315 65386.32
# 2452353 65386.32
# 2763724 65386.32
# 3200875 65386.32
# 3767825 65386.32
# 3948005 65386.32
# 4443971 65386.32
# 4838742 65386.32
# 5290188 65386.32
# 5578482 65386.32

# %% [markdown]
# # Relleno NaN del resto de columnas, son categoricas y salary no podemos saber que salario tenian investigue y decia ponerlo en -999 lo puse en -1

# %%
df.head()
# Out:
#          pk_cid pk_partition  short_term_deposit  loans  mortgage  funds  \
# 1479563   15891   2018-07-28                   0      0         0      0
# 2168122   15891   2018-08-28                   0      0         0      0
# 2962973   16063   2018-11-28                   0      0         0      0
# 3628236   16063   2018-12-28                   0      0         0      0
# 4028169   16063   2019-01-28                   0      0         0      0
#
#          securities  long_term_deposit  em_account_pp  credit_card  payroll  \
# 1479563           0                  0              0            0     0.00
# 2168122           0                  0              0            0     0.00
# 2962973           0                  0              0            0     0.00
# 3628236           0                  0              0            0     0.00
# 4028169           0                  0              0            0     0.00
#
#          pension_plan  payroll_account  emc_account  debit_card  em_account_p  \
# 1479563          0.00                0            0           0             0
# 2168122          0.00                0            0           0             0
# 2962973          0.00                0            0           0             0
# 3628236          0.00                0            0           0             0
# 4028169          0.00                0            0           0             0
#
#          em_acount entry_date entry_channel  active_customer  \
# 1479563          1 2018-07-28           KAT             1.00
# 2168122          0 2018-07-28           KAT             0.00
# 2962973          0 2018-11-19           KAT             1.00
# 3628236          0 2018-11-19           KAT             1.00
# 4028169          0 2018-11-19           KAT             1.00
#
#                    segment country_id  region_code gender  age deceased  \
# 1479563               None         ES        28.00      H   59        N
# 2168122  02 - PARTICULARES         ES        28.00      H   59        N
# 2962973               None         ES        28.00      H   62        N
# 3628236  02 - PARTICULARES         ES        28.00      H   62        N
# 4028169  02 - PARTICULARES         ES        28.00      H   62        N
#
#          salary
# 1479563     NaN
# 2168122     NaN
# 2962973     NaN
# 3628236     NaN
# 4028169     NaN

# %%
df.isna().sum()
# Out:
# pk_cid                      0
# pk_partition                0
# short_term_deposit          0
# loans                       0
# mortgage                    0
# funds                       0
# securities                  0
# long_term_deposit           0
# em_account_pp               0
# credit_card                 0
# payroll                     0
# pension_plan                0
# payroll_account             0
# emc_account                 0
# debit_card                  0
# em_account_p                0
# em_acount                   0
# entry_date                  0
# entry_channel          133033
# active_customer             0
# segment                133944
# country_id                  0
# region_code              2264
# gender                     25
# age                         0
# deceased                    0
# salary                1512103
# dtype: int64

# %%
df[df['entry_channel'].isna()].duplicated().sum()
# Out:
# 0

# %%
df['entry_channel'].fillna('Unknown', inplace=True)

# %%
df.segment.value_counts(dropna=False)
# Out:
# segment
# 03 - UNIVERSITARIO    3900166
# 02 - PARTICULARES     1830875
# None                   133944
# 01 - TOP                97939
# Name: count, dtype: int64

# %%
df[df['segment'].isna()]
# Out:
#           pk_cid pk_partition  short_term_deposit  loans  mortgage  funds  \
# 1479563    15891   2018-07-28                   0      0         0      0
# 2962973    16063   2018-11-28                   0      0         0      0
# 3628238    16203   2018-12-28                   0      0         0      0
# 2171490    16502   2018-09-28                   0      0         0      0
# 4480634    18146   2019-02-28                   0      0         0      0
# ...          ...          ...                 ...    ...       ...    ...
# 5679916  1553685   2019-05-28                   0      0         0      0
# 5679915  1553686   2019-05-28                   0      0         0      0
# 5679914  1553687   2019-05-28                   0      0         0      0
# 5679913  1553688   2019-05-28                   0      0         0      0
# 5679912  1553689   2019-05-28                   0      0         0      0
#
#          securities  long_term_deposit  em_account_pp  credit_card  payroll  \
# 1479563           0                  0              0            0     0.00
# 2962973           0                  0              0            0     0.00
# 3628238           0                  0              0            0     0.00
# 2171490           0                  0              0            0     0.00
# 4480634           0                  0              0            0     0.00
# ...             ...                ...            ...          ...      ...
# 5679916           0                  0              0            0     0.00
# 5679915           0                  0              0            0     0.00
# 5679914           0                  0              0            0     0.00
# 5679913           0                  0              0            0     0.00
# 5679912           0                  0              0            0     0.00
#
#          pension_plan  payroll_account  emc_account  debit_card  em_account_p  \
# 1479563          0.00                0            0           0             0
# 2962973          0.00                0            0           0             0
# 3628238          0.00                0            0           0             0
# 2171490          0.00                0            0           0             0
# 4480634          0.00                0            0           0             0
# ...               ...              ...          ...         ...           ...
# 5679916          0.00                0            0           0             0
# 5679915          0.00                0            0           0             0
# 5679914          0.00                0            0           0             0
# 5679913          0.00                0            0           0             0
# 5679912          0.00                0            0           0             0
#
#          em_acount entry_date entry_channel  active_customer segment  \
# 1479563          1 2018-07-28           KAT             1.00    None
# 2962973          0 2018-11-19           KAT             1.00    None
# 3628238          0 2018-12-23           KAT             0.00    None
# 2171490          0 2018-09-30       Unknown             0.00    None
# 4480634          0 2019-02-23       Unknown             1.00    None
# ...            ...        ...           ...              ...     ...
# 5679916          0 2019-05-31       Unknown             0.00    None
# 5679915          0 2019-05-31       Unknown             0.00    None
# 5679914          0 2019-05-31       Unknown             0.00    None
# 5679913          0 2019-05-31       Unknown             0.00    None
# 5679912          0 2019-05-31       Unknown             0.00    None
#
#         country_id  region_code gender  age deceased  salary
# 1479563         ES        28.00      H   59        N     NaN
# 2962973         ES        28.00      H   62        N     NaN
# 3628238         ES         8.00      V   70        N     NaN
# 2171490         ES        28.00      H   57        N     NaN
# 4480634         ES        28.00      V   65        N     NaN
# ...            ...          ...    ...  ...      ...     ...
# 5679916         ES        13.00      V   52        N     NaN
# 5679915         ES        41.00      H   30        N     NaN
# 5679914         ES        28.00      V   21        N     NaN
# 5679913         ES        39.00      H   43        N     NaN
# 5679912         ES        21.00      V   40        N     NaN
#
# [133944 rows x 27 columns]

# %%
df['segment'].fillna('04 - DESCONOCIDO', inplace=True)

# %%
df.segment.value_counts(dropna=False)
# Out:
# segment
# 03 - UNIVERSITARIO    3900166
# 02 - PARTICULARES     1830875
# 04 - DESCONOCIDO       133944
# 01 - TOP                97939
# Name: count, dtype: int64

# %%
df.describe().T
# Out:
#                         count                           mean  \
# pk_cid             5962924.00                     1234929.80
# pk_partition          5962924  2018-10-30 16:23:50.368324864
# short_term_deposit 5962924.00                           0.00
# loans              5962924.00                           0.00
# mortgage           5962924.00                           0.00
# funds              5962924.00                           0.00
# securities         5962924.00                           0.00
# long_term_deposit  5962924.00                           0.02
# em_account_pp      5962924.00                           0.00
# credit_card        5962924.00                           0.01
# payroll            5962924.00                           0.03
# pension_plan       5962924.00                           0.04
# payroll_account    5962924.00                           0.06
# emc_account        5962924.00                           0.05
# debit_card         5962924.00                           0.09
# em_account_p       5962924.00                           0.00
# em_acount          5962924.00                           0.73
# entry_date            5962924  2017-02-10 18:45:14.368186112
# active_customer    5962924.00                           0.40
# region_code        5960660.00                          25.81
# age                5962924.00                          29.76
# salary             4450821.00                      115816.72
#
#                                     min                  25%  \
# pk_cid                         15891.00           1112532.00
# pk_partition        2018-01-28 00:00:00  2018-07-28 00:00:00
# short_term_deposit                 0.00                 0.00
# loans                              0.00                 0.00
# mortgage                           0.00                 0.00
# funds                              0.00                 0.00
# securities                         0.00                 0.00
# long_term_deposit                  0.00                 0.00
# em_account_pp                      0.00                 0.00
# credit_card                        0.00                 0.00
# payroll                            0.00                 0.00
# pension_plan                       0.00                 0.00
# payroll_account                    0.00                 0.00
# emc_account                        0.00                 0.00
# debit_card                         0.00                 0.00
# em_account_p                       0.00                 0.00
# em_acount                          0.00                 0.00
# entry_date          2015-01-01 00:00:00  2016-01-10 00:00:00
# active_customer                    0.00                 0.00
# region_code                        1.00                13.00
# age                                2.00                22.00
# salary                          1202.73             61500.63
#
#                                     50%                  75%  \
# pk_cid                       1231097.00           1352339.00
# pk_partition        2018-11-28 00:00:00  2019-02-28 00:00:00
# short_term_deposit                 0.00                 0.00
# loans                              0.00                 0.00
# mortgage                           0.00                 0.00
# funds                              0.00                 0.00
# securities                         0.00                 0.00
# long_term_deposit                  0.00                 0.00
# em_account_pp                      0.00                 0.00
# credit_card                        0.00                 0.00
# payroll                            0.00                 0.00
# pension_plan                       0.00                 0.00
# payroll_account                    0.00                 0.00
# emc_account                        0.00                 0.00
# debit_card                         0.00                 0.00
# em_account_p                       0.00                 0.00
# em_acount                          1.00                 1.00
# entry_date          2016-12-31 00:00:00  2017-11-14 00:00:00
# active_customer                    0.00                 1.00
# region_code                       28.00                36.00
# age                               25.00                34.00
# salary                         88654.65            131669.91
#
#                                     max       std
# pk_cid                       1553689.00 162302.04
# pk_partition        2019-05-28 00:00:00       NaN
# short_term_deposit                 1.00      0.05
# loans                              1.00      0.01
# mortgage                           1.00      0.01
# funds                              1.00      0.06
# securities                         1.00      0.06
# long_term_deposit                  1.00      0.13
# em_account_pp                      0.00      0.00
# credit_card                        1.00      0.11
# payroll                            1.00      0.18
# pension_plan                       1.00      0.19
# payroll_account                    1.00      0.23
# emc_account                        1.00      0.23
# debit_card                         1.00      0.29
# em_account_p                       1.00      0.00
# em_acount                          1.00      0.44
# entry_date          2019-05-31 00:00:00       NaN
# active_customer                    1.00      0.49
# region_code                       52.00     13.60
# age                              105.00     11.98
# salary                      28894395.51 199551.89

# %%
df.region_code.value_counts(dropna=False)
# Out:
# region_code
# 28.00    1185757
# 8.00      600362
# 46.00     358142
# 30.00     296856
# 41.00     290447
# 15.00     254891
# 29.00     187911
# 36.00     175850
# 3.00      171358
# 11.00     160894
# 33.00     134562
# 50.00     132983
# 6.00      122587
# 35.00     121982
# 47.00     116948
# 18.00     102789
# 45.00     102328
# 37.00      92538
# 10.00      83283
# 14.00      75405
# 2.00       72071
# 21.00      72037
# 13.00      70092
# 39.00      69589
# 12.00      68709
# 7.00       62436
# 32.00      54639
# 27.00      52783
# 43.00      51782
# 17.00      50749
# 9.00       47746
# 25.00      46887
# 16.00      36094
# 24.00      35426
# 48.00      35256
# 26.00      34790
# 4.00       32680
# 31.00      31241
# 49.00      30965
# 23.00      30955
# 38.00      29001
# 34.00      27545
# 19.00      26762
# 40.00      21658
# 5.00       21300
# 22.00      21112
# 20.00      18833
# 1.00       12999
# 44.00      12616
# 42.00       8500
# 51.00       2896
# 52.00       2638
# NaN         2264
# Name: count, dtype: int64

# %%
df[df['region_code'].isna()]
# Out:
#           pk_cid pk_partition  short_term_deposit  loans  mortgage  funds  \
# 240946    130419   2018-02-28                   0      0         0      0
# 483522    130419   2018-03-28                   0      0         0      0
# 728777    130419   2018-04-28                   0      0         0      0
# 1223095   130419   2018-05-28                   0      0         0      0
# 1479139   130419   2018-07-28                   0      0         0      0
# ...          ...          ...                 ...    ...       ...    ...
# 5083649  1530982   2019-04-28                   0      0         0      0
# 5692590  1530982   2019-05-28                   0      0         0      0
# 5672371  1542679   2019-05-28                   0      0         0      0
# 5097292  1544346   2019-04-28                   0      0         0      0
# 5682097  1544346   2019-05-28                   0      0         0      1
#
#          securities  long_term_deposit  em_account_pp  credit_card  payroll  \
# 240946            0                  0              0            1     0.00
# 483522            0                  0              0            0     0.00
# 728777            0                  0              0            1     0.00
# 1223095           0                  0              0            0     0.00
# 1479139           0                  0              0            0     0.00
# ...             ...                ...            ...          ...      ...
# 5083649           0                  0              0            0     0.00
# 5692590           0                  0              0            0     1.00
# 5672371           0                  0              0            0     0.00
# 5097292           0                  0              0            0     0.00
# 5682097           0                  0              0            0     0.00
#
#          pension_plan  payroll_account  emc_account  debit_card  em_account_p  \
# 240946           0.00                0            0           0             0
# 483522           0.00                0            0           0             0
# 728777           0.00                0            0           0             0
# 1223095          0.00                0            0           0             0
# 1479139          0.00                0            0           0             0
# ...               ...              ...          ...         ...           ...
# 5083649          0.00                0            0           0             0
# 5692590          1.00                1            0           0             0
# 5672371          0.00                0            0           0             0
# 5097292          0.00                0            0           0             0
# 5682097          0.00                0            0           0             0
#
#          em_acount entry_date entry_channel  active_customer  \
# 240946           0 2017-12-31           KAT             0.00
# 483522           0 2017-12-31           KAT             0.00
# 728777           0 2017-12-31           KAT             0.00
# 1223095          0 2017-12-31           KAT             0.00
# 1479139          0 2017-12-31           KAT             0.00
# ...            ...        ...           ...              ...
# 5083649          1 2019-02-09           KAT             1.00
# 5692590          0 2019-02-09           KAT             1.00
# 5672371          1 2019-03-31           KHM             1.00
# 5097292          1 2019-04-08       Unknown             1.00
# 5682097          1 2019-04-08           KFA             1.00
#
#                    segment country_id  region_code gender  age deceased  \
# 240946   02 - PARTICULARES         US          NaN      V   53        N
# 483522   02 - PARTICULARES         US          NaN      V   53        N
# 728777   02 - PARTICULARES         US          NaN      V   53        N
# 1223095  02 - PARTICULARES         US          NaN      V   53        N
# 1479139  02 - PARTICULARES         US          NaN      V   53        N
# ...                    ...        ...          ...    ...  ...      ...
# 5083649  02 - PARTICULARES         GB          NaN      V   33        N
# 5692590  02 - PARTICULARES         GB          NaN      V   33        N
# 5672371  02 - PARTICULARES         US          NaN      V   64        N
# 5097292   04 - DESCONOCIDO         FR          NaN      H   46        N
# 5682097  02 - PARTICULARES         FR          NaN      H   46        N
#
#          salary
# 240946      NaN
# 483522      NaN
# 728777      NaN
# 1223095     NaN
# 1479139     NaN
# ...         ...
# 5083649     NaN
# 5692590     NaN
# 5672371     NaN
# 5097292     NaN
# 5682097     NaN
#
# [2264 rows x 27 columns]

# %%
df['region_code'].fillna(99, inplace=True)

# %%
df.gender.value_counts(dropna=False)
# Out:
# gender
# H       3087502
# V       2875397
# None         25
# Name: count, dtype: int64

# %%
df['gender'].fillna('X', inplace=True)

# %%
df.salary.describe()
# Out:
# count    4450821.00
# mean      115816.72
# std       199551.89
# min         1202.73
# 25%        61500.63
# 50%        88654.65
# 75%       131669.91
# max     28894395.51
# Name: salary, dtype: float64

# %%
df['salary'].fillna(-1, inplace=True)

# %%
df.isna().sum()
# Out:
# pk_cid                0
# pk_partition          0
# short_term_deposit    0
# loans                 0
# mortgage              0
# funds                 0
# securities            0
# long_term_deposit     0
# em_account_pp         0
# credit_card           0
# payroll               0
# pension_plan          0
# payroll_account       0
# emc_account           0
# 2943633     0.00          0.00                0            0           0
# 2962972     0.00          0.00                0            0           0
# 3628237     0.00          0.00                0            0           0
# 4028330     0.00          0.00                0            1           0
#
#          em_account_p  em_acount
# 1479563             0          1
# 2168122             0          0
# 2962973             0          0
# 3628236             0          0
# 4028169             0          0
# 4480637             0          0
# 4876040             0          0
# 5134317             0          0
# 5523397             0          0
# 3628238             0          0
# 4028170             0          1
# 4480636             0          1
# 4876039             0          1
# 5134321             0          1
# 5523396             0          1
# 2171490             0          0
# 2943633             0          1
# 2962972             0          1
# 3628237             0          1
# 4028330             0          1

# %%
products_sorted['em_acount_previous_month'] = products_sorted.groupby('pk_cid')['em_acount'].shift(1)

# %%
products_sorted.head()
# Out:
#          Unnamed: 0  pk_cid pk_partition  short_term_deposit  loans  mortgage  \
# 1479563     4078994   15891   2018-07-28                   0      0         0
# 2168122     5319232   15891   2018-08-28                   0      0         0
# 2962973     7451107   16063   2018-11-28                   0      0         0
# 3628236     8617948   16063   2018-12-28                   0      0         0
# 4028169     9401149   16063   2019-01-28                   0      0         0
#
#          funds  securities  long_term_deposit  em_account_pp  credit_card  \
# 1479563      0           0                  0              0            0
# 2168122      0           0                  0              0            0
# 2962973      0           0                  0              0            0
# 3628236      0           0                  0              0            0
# 4028169      0           0                  0              0            0
#
#          payroll  pension_plan  payroll_account  emc_account  debit_card  \
# 1479563     0.00          0.00                0            0           0
# 2168122     0.00          0.00                0            0           0
# 2962973     0.00          0.00                0            0           0
# 3628236     0.00          0.00                0            0           0
# 4028169     0.00          0.00                0            0           0
#
#          em_account_p  em_acount  em_acount_previous_month
# 1479563             0          1                       NaN
# 2168122             0          0                      1.00
# 2962973             0          0                       NaN
# 3628236             0          0                      0.00
# 4028169             0          0                      0.00

# %%
df['dif_em_acount'] = df['em_acount'] - df['em_acount_previous_month']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'em_acount_previous_month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df['dif_em_acount'] = df['em_acount'] - df['em_acount_previous_month']
#
# File d:\Anaconda\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File d:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'em_acount_previous_month'

# %%
df['dif_em_acount'].value_counts()
# Out:
# dif_em_acount
# 0.00     5414693
# -1.00      50919
# 1.00       40939
# Name: count, dtype: int64

# %%
df[df['dif_em_acount'] == -1].pivot_table(index='pk_partition', values='dif_em_acount', aggfunc=[len])
# Out:
#                        len
#              dif_em_acount
# pk_partition
# 2018-02-28            2351
# 2018-03-28            2436
# 2018-04-28            2433
# 2018-05-28            2290
# 2018-06-28            2466
# 2018-07-28            3386
# 2018-08-28            3222
# 2018-09-28            3158
# 2018-10-28            3454
# 2018-11-28            4137
# 2018-12-28            4019
# 2019-01-28            3419
# 2019-02-28            3769
# 2019-03-28            3472
# 2019-04-28            3423
# 2019-05-28            3484

# %%
df[df['dif_em_acount'] == 1].pivot_table(index='pk_partition', values='dif_em_acount', aggfunc=[len])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dif_em_acount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df[df['dif_em_acount'] == 1].pivot_table(index='pk_partition', values='dif_em_acount', aggfunc=[len])
#
# File d:\Anaconda\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File d:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'dif_em_acount'
