# %% [markdown]
# # Personalización de Campaña de Marketing: Segmentación de Clientes
#
# El objetivo de este análisis es realizar una **segmentación de clientes** para personalizar una campaña de e-mail dirigida a **10,000 clientes**. Utilizaremos el algoritmo **K-Nearest Neighbors (KNN)** para agrupar a los clientes en **4 o 5 segmentos**, basándonos en características demográficas clave y en su **probabilidad de compra**.
#
# ## Contexto
#
# Siguiendo la sugerencia del equipo de marketing, liderado por **Erin**, se acordó que la segmentación se basaría en datos demográficos como:
#
# - **Edad**
# - **Sexo**
# - **Ingresos**
#
# Este enfoque permitirá crear perfiles específicos que servirán para personalizar las creatividades y mensajes de la campaña de e-mail, mejorando la efectividad de la comunicación y maximizando las tasas de conversión.
#
# ## Objetivo
#
# Crear segmentos de clientes bien definidos, de modo que las **4 o 5 creatividades** de la campaña se alineen con los perfiles identificados. Esto permitirá que la campaña sea más relevante y efectiva para cada grupo, lo que podría aumentar significativamente las probabilidades de éxito de la campaña de venta de **tarjetas de crédito**.

# %%
import numpy as np 
import pandas as pd
pd.options.display.float_format = '{:,.3f}'.format
pd.set_option('display.max_columns', 100)
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import RobustScaler,OneHotEncoder
from sklearn.cluster import KMeans

# %%
# Leer dataframe con los datos de los 10000 clientes.

df_seleccionados = pd.read_parquet(r'C:\Users\Usuario\Desktop\Nuclio\TFM_Nuclio\easy_money_project\Tarea_3_Recomendación\top_customers_no_credit_card.parquet')

# %%
df_seleccionados
# Out:
#         pk_partition  short_term_deposit  loans  mortgage  funds  securities  \
# pk_cid
# 1200307   2019-05-28                   0      0         1      0           0
# 330599    2019-05-28                   0      0         1      1           0
# 1136531   2019-05-28                   0      0         1      0           0
# 1138692   2019-05-28                   0      0         1      0           0
# 1258071   2019-05-28                   0      0         1      0           0
# ...              ...                 ...    ...       ...    ...         ...
# 1108774   2019-05-28                   0      0         0      0           0
# 1298291   2019-05-28                   0      0         0      0           0
# 1209693   2019-05-28                   0      0         0      0           0
# 1120992   2019-05-28                   0      0         0      0           0
# 1165902   2019-05-28                   0      0         0      0           0
#
#          long_term_deposit  em_account_pp  credit_card  payroll  pension_plan  \
# pk_cid
# 1200307                  0              0            0        1             1
# 330599                   0              0            0        1             1
# 1136531                  0              0            0        1             1
# 1138692                  0              0            0        1             1
# 1258071                  0              0            0        0             0
# ...                    ...            ...          ...      ...           ...
# 1108774                  0              0            0        1             1
# 1298291                  0              0            0        1             1
# 1209693                  0              0            0        1             1
# 1120992                  0              0            0        0             0
# 1165902                  0              0            0        0             0
#
#          payroll_account  emc_account  debit_card  em_account_p  em_acount  \
# pk_cid
# 1200307                1            0           1             0          0
# 330599                 1            1           1             0          0
# 1136531                1            0           1             0          0
# 1138692                1            0           1             0          0
# 1258071                0            0           0             0          0
# ...                  ...          ...         ...           ...        ...
# 1108774                1            0           1             0          0
# 1298291                1            1           1             0          1
# 1209693                1            0           1             0          0
# 1120992                0            0           0             0          0
# 1165902                0            0           0             0          0
#
#          num_products_contracts  p_cuenta_bancaria  cuentas_sum  p_inversion  \
# pk_cid
# 1200307                       5                  1            3            1
# 330599                        7                  1            4            1
# 1136531                       5                  1            3            1
# 1138692                       5                  1            3            1
# 1258071                       1                  0            0            0
# ...                         ...                ...          ...          ...
# 1108774                       4                  1            3            1
# 1298291                       6                  1            5            1
# 1209693                       4                  1            3            1
# 1120992                       0                  0            0            0
# 1165902                       0                  0            0            0
#
#          inversion_sum  p_financiacion  financiacion_sum  profit_cuentas  \
# pk_cid
# 1200307              1               1                 1              30
# 330599               2               1                 1              40
# 1136531              1               1                 1              30
# 1138692              1               1                 1              30
# 1258071              0               1                 1               0
# ...                ...             ...               ...             ...
# 1108774              1               0                 0              30
# 1298291              1               0                 0              50
# 1209693              1               0                 0              30
# 1120992              0               0                 0               0
# 1165902              0               0                 0               0
#
#          profit_inversion  profit_financiacion country_id gender  \
# pk_cid
# 1200307                40                   60         ES      V
# 330599                 80                   60         ES      H
# 1136531                40                   60         ES      H
# 1138692                40                   60         ES      V
# 1258071                 0                   60         ES      V
# ...                   ...                  ...        ...    ...
# 1108774                40                    0         ES      H
# 1298291                40                    0         ES      V
# 1209693                40                    0         ES      H
# 1120992                 0                    0         ES      H
# 1165902                 0                    0         ES      H
#
#          mes_partition mes_nombre_partition       grupo_edad  median_salary  \
# pk_cid
# 1200307              5                  May  Adultos mayores    937,306.320
# 330599               5                  May  Adultos mayores    314,597.850
# 1136531              5                  May  Adultos jóvenes    236,739.840
# 1138692              5                  May          Adultos    265,487.490
# 1258071              5                  May          Adultos    714,033.300
# ...                ...                  ...              ...            ...
# 1108774              5                  May  Adultos jóvenes    154,672.140
# 1298291              5                  May          Adultos    129,719.160
# 1209693              5                  May  Adultos jóvenes     66,520.140
# 1120992              5                  May          Adultos    143,527.110
# 1165902              5                  May          Adultos    147,332.340
#
#         region_code entry_date entry_channel  active_customer  \
# pk_cid
# 1200307      Madrid 2016-10-15           KFC                1
# 330599       Madrid 2016-11-21           KFA                1
# 1136531      Madrid 2016-06-06           KAT                1
# 1138692      Madrid 2016-06-27           KFC                1
# 1258071      Madrid 2017-09-17           KFA                1
# ...             ...        ...           ...              ...
# 1108774     Sevilla 2015-12-03           KHE                1
# 1298291       Cádiz 2017-08-22           KFC                1
# 1209693    Asturias 2016-10-28           KFC                1
# 1120992      Madrid 2016-10-15           KAT                0
# 1165902      Madrid 2016-08-14           KAT                0
#
#                     segment categoria_antiguedad  sale_credit_card  \
# pk_cid
# 1200307   02 - PARTICULARES             2-3 años                 0
# 330599    02 - PARTICULARES             2-3 años                 0
# 1136531   02 - PARTICULARES        Más de 3 años                 0
# 1138692   02 - PARTICULARES             2-3 años                 0
# 1258071   02 - PARTICULARES             1-2 años                 0
# ...                     ...                  ...               ...
# 1108774   02 - PARTICULARES        Más de 3 años                 0
# 1298291   02 - PARTICULARES             1-2 años                 0
# 1209693  03 - UNIVERSITARIO             2-3 años                 0
# 1120992   02 - PARTICULARES             2-3 años                 0
# 1165902   02 - PARTICULARES             2-3 años                 0
#
#          sale_short_term_deposit  sale_loans  sale_mortgage  sale_funds  \
# pk_cid
# 1200307                        0           0              1           0
# 330599                         0           0              1           1
# 1136531                        0           0              1           0
# 1138692                        0           0              1           0
# 1258071                        0           0              1           0
# ...                          ...         ...            ...         ...
# 1108774                        0           0              0           0
# 1298291                        0           0              0           0
# 1209693                        0           0              0           0
# 1120992                        0           0              0           0
# 1165902                        0           0              0           0
#
#          sale_securities  sale_long_term_deposit  sale_em_account_pp  \
# pk_cid
# 1200307                0                       0                   0
# 330599                 0                       0                   0
# 1136531                0                       0                   0
# 1138692                0                       0                   0
# 1258071                0                       0                   0
# ...                  ...                     ...                 ...
# 1108774                0                       0                   0
# 1298291                0                       0                   0
# 1209693                0                       0                   0
# 1120992                0                       0                   0
# 1165902                0                       0                   0
#
#          sale_payroll  sale_pension_plan  sale_payroll_account  \
# pk_cid
# 1200307             1                  1                     1
# 330599              1                  1                     1
# 1136531             1                  1                     1
# 1138692             1                  1                     1
# 1258071             0                  0                     0
# ...               ...                ...                   ...
# 1108774             1                  1                     1
# 1298291             1                  1                     1
# 1209693             1                  1                     1
# 1120992             0                  0                     0
# 1165902             0                  0                     0
#
#          sale_emc_account  sale_debit_card  sale_em_account_p  sale_em_acount  \
# pk_cid
# 1200307                 0                1                  0               0
# 330599                  1                1                  0               0
# 1136531                 0                1                  0               0
# 1138692                 0                1                  0               0
# 1258071                 0                0                  0               0
# ...                   ...              ...                ...             ...
# 1108774                 0                1                  0               0
# 1298291                 1                1                  0               1
# 1209693                 1                1                  0               0
# 1120992                 0                1                  0               1
# 1165902                 0                1                  0               1
#
#          probability
# pk_cid
# 1200307        1.000
# 330599         1.000
# 1136531        1.000
# 1138692        1.000
# 1258071        1.000
# ...              ...
# 1108774        0.701
# 1298291        0.701
# 1209693        0.701
# 1120992        0.701
# 1165902        0.701
#
# [10000 rows x 54 columns]

# %%
# Listar las columnas a eliminar
columns_to_drop = [
    'pk_partition',
    'short_term_deposit',
    'loans',
    'mortgage',
    'funds',
    'securities',
    'long_term_deposit',
    'em_account_pp',
    'credit_card',
    'payroll',
    'pension_plan',
    'payroll_account',
    'emc_account',
    'debit_card',
    'em_account_p',
    'em_acount',
    'num_products_contracts',
    'p_cuenta_bancaria',
    'cuentas_sum',
    'p_inversion',
    'inversion_sum',
    'p_financiacion',
    'financiacion_sum',
    'profit_cuentas',
    'profit_inversion',
    'profit_financiacion',
    'country_id',
    'mes_nombre_partition',
    'sale_credit_card',
    'sale_short_term_deposit',
    'sale_loans',
    'sale_mortgage',
    'sale_funds',
    'sale_securities',
    'sale_long_term_deposit',
    'sale_em_account_pp',
    'sale_payroll',
    'sale_pension_plan',
    'sale_payroll_account',
    'sale_emc_account',
    'sale_debit_card',
    'sale_em_account_p',
    'sale_em_acount'
]

# Eliminar las columnas del DataFrame
df_seleccionados.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
df_seleccionados
# Out:
#         gender  mes_partition       grupo_edad  median_salary region_code  \
# pk_cid
# 1200307      V              5  Adultos mayores    937,306.320      Madrid
# 330599       H              5  Adultos mayores    314,597.850      Madrid
# 1136531      H              5  Adultos jóvenes    236,739.840      Madrid
# 1138692      V              5          Adultos    265,487.490      Madrid
# 1258071      V              5          Adultos    714,033.300      Madrid
# ...        ...            ...              ...            ...         ...
# 1108774      H              5  Adultos jóvenes    154,672.140     Sevilla
# 1298291      V              5          Adultos    129,719.160       Cádiz
# 1209693      H              5  Adultos jóvenes     66,520.140    Asturias
# 1120992      H              5          Adultos    143,527.110      Madrid
# 1165902      H              5          Adultos    147,332.340      Madrid
#
#         entry_date entry_channel  active_customer             segment  \
# pk_cid
# 1200307 2016-10-15           KFC                1   02 - PARTICULARES
# 330599  2016-11-21           KFA                1   02 - PARTICULARES
# 1136531 2016-06-06           KAT                1   02 - PARTICULARES
# 1138692 2016-06-27           KFC                1   02 - PARTICULARES
# 1258071 2017-09-17           KFA                1   02 - PARTICULARES
# ...            ...           ...              ...                 ...
# 1108774 2015-12-03           KHE                1   02 - PARTICULARES
# 1298291 2017-08-22           KFC                1   02 - PARTICULARES
# 1209693 2016-10-28           KFC                1  03 - UNIVERSITARIO
# 1120992 2016-10-15           KAT                0   02 - PARTICULARES
# 1165902 2016-08-14           KAT                0   02 - PARTICULARES
#
#         categoria_antiguedad  probability
# pk_cid
# 1200307             2-3 años        1.000
# 330599              2-3 años        1.000
# 1136531        Más de 3 años        1.000
# 1138692             2-3 años        1.000
# 1258071             1-2 años        1.000
# ...                      ...          ...
# 1108774        Más de 3 años        0.701
# 1298291             1-2 años        0.701
# 1209693             2-3 años        0.701
# 1120992             2-3 años        0.701
# 1165902             2-3 años        0.701
#
# [10000 rows x 11 columns]

# %%
df_seleccionados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1200307 to 1165902
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gender                10000 non-null  object
#  1   mes_partition         10000 non-null  int32
#  2   grupo_edad            10000 non-null  object
#  3   median_salary         10000 non-null  float64
#  4   region_code           10000 non-null  object
#  5   entry_date            10000 non-null  datetime64[ns]
#  6   entry_channel         10000 non-null  object
#  7   active_customer       10000 non-null  int32
#  8   segment               10000 non-null  category
#  9   categoria_antiguedad  10000 non-null  category
#  10  probability           10000 non-null  float32
# dtypes: category(2), datetime64[ns](1), float32(1), float64(1), int32(2), object(4)
# memory usage: 684.1+ KB

# %%
df_seleccionados = df_seleccionados.reset_index()
df_seleccionados.rename(columns={'index': 'pk_cid'}, inplace=True)

# %%
df_seleccionados.duplicated().sum()
# Out:
# 0

# %%
df_seleccionados
# Out:
#        pk_cid gender  mes_partition       grupo_edad  median_salary  \
# 0     1200307      V              5  Adultos mayores    937,306.320
# 1      330599      H              5  Adultos mayores    314,597.850
# 2     1136531      H              5  Adultos jóvenes    236,739.840
# 3     1138692      V              5          Adultos    265,487.490
# 4     1258071      V              5          Adultos    714,033.300
# ...       ...    ...            ...              ...            ...
# 9995  1108774      H              5  Adultos jóvenes    154,672.140
# 9996  1298291      V              5          Adultos    129,719.160
# 9997  1209693      H              5  Adultos jóvenes     66,520.140
# 9998  1120992      H              5          Adultos    143,527.110
# 9999  1165902      H              5          Adultos    147,332.340
#
#      region_code entry_date entry_channel  active_customer  \
# 0         Madrid 2016-10-15           KFC                1
# 1         Madrid 2016-11-21           KFA                1
# 2         Madrid 2016-06-06           KAT                1
# 3         Madrid 2016-06-27           KFC                1
# 4         Madrid 2017-09-17           KFA                1
# ...          ...        ...           ...              ...
# 9995     Sevilla 2015-12-03           KHE                1
# 9996       Cádiz 2017-08-22           KFC                1
# 9997    Asturias 2016-10-28           KFC                1
# 9998      Madrid 2016-10-15           KAT                0
# 9999      Madrid 2016-08-14           KAT                0
#
#                  segment categoria_antiguedad  probability
# 0      02 - PARTICULARES             2-3 años        1.000
# 1      02 - PARTICULARES             2-3 años        1.000
# 2      02 - PARTICULARES        Más de 3 años        1.000
# 3      02 - PARTICULARES             2-3 años        1.000
# 4      02 - PARTICULARES             1-2 años        1.000
# ...                  ...                  ...          ...
# 9995   02 - PARTICULARES        Más de 3 años        0.701
# 9996   02 - PARTICULARES             1-2 años        0.701
# 9997  03 - UNIVERSITARIO             2-3 años        0.701
# 9998   02 - PARTICULARES             2-3 años        0.701
# 9999   02 - PARTICULARES             2-3 años        0.701
#
# [10000 rows x 12 columns]

# %%
# sociodemografico
sdg_df_cleaned = pd.read_parquet('https://easy-money-project-bucket.s3.eu-west-3.amazonaws.com/sociodemographic_df_adrian.parquet')

# %%
sdg_df_cleaned
# Out:
#           pk_cid pk_partition country_id  region_code gender  age      salary  \
# 0          15891   2018-07-28         ES       Madrid      H   59 102,377.400
# 1          15891   2018-08-28         ES       Madrid      H   59 132,384.450
# 2          16063   2018-11-28         ES       Madrid      H   62 102,377.400
# 3          16063   2018-12-28         ES       Madrid      H   62 132,384.450
# 4          16063   2019-01-28         ES       Madrid      H   62 132,384.450
# ...          ...          ...        ...          ...    ...  ...         ...
# 5962919  1553685   2019-05-28         ES  Ciudad Real      V   52 114,633.765
# 5962920  1553686   2019-05-28         ES      Sevilla      H   30  85,787.220
# 5962921  1553687   2019-05-28         ES       Madrid      V   21 143,419.770
# 5962922  1553688   2019-05-28         ES    Cantabria      H   43 114,633.765
# 5962923  1553689   2019-05-28         ES       Huelva      V   40 114,633.765
#
#          mes_partition mes_nombre_partition       grupo_edad
# 0                    7                 July  Adultos mayores
# 1                    8               August  Adultos mayores
# 2                   11             November  Adultos mayores
# 3                   12             December  Adultos mayores
# 4                    1              January  Adultos mayores
# ...                ...                  ...              ...
# 5962919              5                  May          Adultos
# 5962920              5                  May  Adultos jóvenes
# 5962921              5                  May          Jóvenes
# 5962922              5                  May          Adultos
# 5962923              5                  May          Adultos
#
# [5962924 rows x 10 columns]

# %%
sdg_last = sdg_df_cleaned[sdg_df_cleaned["pk_partition"] == "2019-05-28"]

# %%
df_joined = df_seleccionados.merge(sdg_last[['pk_cid', 'age']], on='pk_cid', how='left')

# %%
df_joined
# Out:
#        pk_cid gender  mes_partition       grupo_edad  median_salary  \
# 0     1200307      V              5  Adultos mayores    937,306.320
# 1      330599      H              5  Adultos mayores    314,597.850
# 2     1136531      H              5  Adultos jóvenes    236,739.840
# 3     1138692      V              5          Adultos    265,487.490
# 4     1258071      V              5          Adultos    714,033.300
# ...       ...    ...            ...              ...            ...
# 9995  1108774      H              5  Adultos jóvenes    154,672.140
# 9996  1298291      V              5          Adultos    129,719.160
# 9997  1209693      H              5  Adultos jóvenes     66,520.140
# 9998  1120992      H              5          Adultos    143,527.110
# 9999  1165902      H              5          Adultos    147,332.340
#
#      region_code entry_date entry_channel  active_customer  \
# 0         Madrid 2016-10-15           KFC                1
# 1         Madrid 2016-11-21           KFA                1
# 2         Madrid 2016-06-06           KAT                1
# 3         Madrid 2016-06-27           KFC                1
# 4         Madrid 2017-09-17           KFA                1
# ...          ...        ...           ...              ...
# 9995     Sevilla 2015-12-03           KHE                1
# 9996       Cádiz 2017-08-22           KFC                1
# 9997    Asturias 2016-10-28           KFC                1
# 9998      Madrid 2016-10-15           KAT                0
# 9999      Madrid 2016-08-14           KAT                0
#
#                  segment categoria_antiguedad  probability  age
# 0      02 - PARTICULARES             2-3 años        1.000   55
# 1      02 - PARTICULARES             2-3 años        1.000   60
# 2      02 - PARTICULARES        Más de 3 años        1.000   38
# 3      02 - PARTICULARES             2-3 años        1.000   51
# 4      02 - PARTICULARES             1-2 años        1.000   53
# ...                  ...                  ...          ...  ...
# 9995   02 - PARTICULARES        Más de 3 años        0.701   34
# 9996   02 - PARTICULARES             1-2 años        0.701   51
# 9997  03 - UNIVERSITARIO             2-3 años        0.701   30
# 9998   02 - PARTICULARES             2-3 años        0.701   40
# 9999   02 - PARTICULARES             2-3 años        0.701   47
#
# [10000 rows x 13 columns]

# %% [markdown]
# Ya tenemos el dataframe con todos los datos de los 10.000 clientes para la segmentacion

# %%
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   pk_cid                10000 non-null  int64
#  1   gender                10000 non-null  object
#  2   mes_partition         10000 non-null  int32
#  3   grupo_edad            10000 non-null  object
#  4   median_salary         10000 non-null  float64
#  5   region_code           10000 non-null  object
#  6   entry_date            10000 non-null  datetime64[ns]
#  7   entry_channel         10000 non-null  object
#  8   active_customer       10000 non-null  int32
#  9   segment               10000 non-null  category
#  10  categoria_antiguedad  10000 non-null  category
#  11  probability           10000 non-null  float32
#  12  age                   10000 non-null  int64
# dtypes: category(2), datetime64[ns](1), float32(1), float64(1), int32(2), int64(2), object(4)
# memory usage: 762.3+ KB

# %%
# Contar el número de filas duplicadas
num_duplicated = df_joined.duplicated().sum()

# Mostrar el número de filas duplicadas
print(f"Número de filas duplicadas: {num_duplicated}")
# Out:
# Número de filas duplicadas: 0

# %%
# Contar el número de filas duplicadas
num_null = df_joined.isna().sum().sum()

# Mostrar el número de filas duplicadas
print(f"Número de valores nulos: {num_null}")
# Out:
# Número de valores nulos: 0

# %% [markdown]
# Despues de comprobar que el dataset no tiene ni valores nulos ni duplicados, seleccionaremos las variables que utilizaremos para la segmentacion.

# %% [markdown]
# ## Limpieza de atributos

# %% [markdown]
# Los valores de fechas serán eliminados y la variable de categoría "antigüedad" también será eliminada. Sin embargo, esta variable puede ser interesante, por lo que calcularemos una nueva que represente los meses de antigüedad para poder usarla en la segmentación.

# %%
# Fecha fija para la comparación
fecha_referencia = pd.to_datetime('2019-05-28')

# Calcular los meses de antigüedad
df_joined['meses_antiguedad'] = ((fecha_referencia - df_joined['entry_date']).dt.days // 30).astype(int)

# %%
df_joined
# Out:
#        pk_cid gender  mes_partition       grupo_edad  median_salary  \
# 0     1200307      V              5  Adultos mayores    937,306.320
# 1      330599      H              5  Adultos mayores    314,597.850
# 2     1136531      H              5  Adultos jóvenes    236,739.840
# 3     1138692      V              5          Adultos    265,487.490
# 4     1258071      V              5          Adultos    714,033.300
# ...       ...    ...            ...              ...            ...
# 9995  1108774      H              5  Adultos jóvenes    154,672.140
# 9996  1298291      V              5          Adultos    129,719.160
# 9997  1209693      H              5  Adultos jóvenes     66,520.140
# 9998  1120992      H              5          Adultos    143,527.110
# 9999  1165902      H              5          Adultos    147,332.340
#
#      region_code entry_date entry_channel  active_customer  \
# 0         Madrid 2016-10-15           KFC                1
# 1         Madrid 2016-11-21           KFA                1
# 2         Madrid 2016-06-06           KAT                1
# 3         Madrid 2016-06-27           KFC                1
# 4         Madrid 2017-09-17           KFA                1
# ...          ...        ...           ...              ...
# 9995     Sevilla 2015-12-03           KHE                1
# 9996       Cádiz 2017-08-22           KFC                1
# 9997    Asturias 2016-10-28           KFC                1
# 9998      Madrid 2016-10-15           KAT                0
# 9999      Madrid 2016-08-14           KAT                0
#
#                  segment categoria_antiguedad  probability  age  \
# 0      02 - PARTICULARES             2-3 años        1.000   55
# 1      02 - PARTICULARES             2-3 años        1.000   60
# 2      02 - PARTICULARES        Más de 3 años        1.000   38
# 3      02 - PARTICULARES             2-3 años        1.000   51
# 4      02 - PARTICULARES             1-2 años        1.000   53
# ...                  ...                  ...          ...  ...
# 9995   02 - PARTICULARES        Más de 3 años        0.701   34
# 9996   02 - PARTICULARES             1-2 años        0.701   51
# 9997  03 - UNIVERSITARIO             2-3 años        0.701   30
# 9998   02 - PARTICULARES             2-3 años        0.701   40
# 9999   02 - PARTICULARES             2-3 años        0.701   47
#
#       meses_antiguedad
# 0                   31
# 1                   30
# 2                   36
# 3                   35
# 4                   20
# ...                ...
# 9995                42
# 9996                21
# 9997                31
# 9998                31
# 9999                33
#
# [10000 rows x 14 columns]

# %%
# Eliminar columnas de fechas
df_joined.drop('categoria_antiguedad', axis=1, inplace=True)
df_joined.drop('entry_date', axis=1, inplace=True)

# %%
df_joined
# Out:
#        pk_cid gender  mes_partition       grupo_edad  median_salary  \
# 0     1200307      V              5  Adultos mayores    937,306.320
# 1      330599      H              5  Adultos mayores    314,597.850
# 2     1136531      H              5  Adultos jóvenes    236,739.840
# 3     1138692      V              5          Adultos    265,487.490
# 4     1258071      V              5          Adultos    714,033.300
# ...       ...    ...            ...              ...            ...
# 9995  1108774      H              5  Adultos jóvenes    154,672.140
# 9996  1298291      V              5          Adultos    129,719.160
# 9997  1209693      H              5  Adultos jóvenes     66,520.140
# 9998  1120992      H              5          Adultos    143,527.110
# 9999  1165902      H              5          Adultos    147,332.340
#
#      region_code entry_channel  active_customer             segment  \
# 0         Madrid           KFC                1   02 - PARTICULARES
# 1         Madrid           KFA                1   02 - PARTICULARES
# 2         Madrid           KAT                1   02 - PARTICULARES
# 3         Madrid           KFC                1   02 - PARTICULARES
# 4         Madrid           KFA                1   02 - PARTICULARES
# ...          ...           ...              ...                 ...
# 9995     Sevilla           KHE                1   02 - PARTICULARES
# 9996       Cádiz           KFC                1   02 - PARTICULARES
# 9997    Asturias           KFC                1  03 - UNIVERSITARIO
# 9998      Madrid           KAT                0   02 - PARTICULARES
# 9999      Madrid           KAT                0   02 - PARTICULARES
#
#       probability  age  meses_antiguedad
# 0           1.000   55                31
# 1           1.000   60                30
# 2           1.000   38                36
# 3           1.000   51                35
# 4           1.000   53                20
# ...           ...  ...               ...
# 9995        0.701   34                42
# 9996        0.701   51                21
# 9997        0.701   30                31
# 9998        0.701   40                31
# 9999        0.701   47                33
#
# [10000 rows x 12 columns]

# %% [markdown]
# ## Meses de antigüedad

# %%
# Grafico meses antiguedad
plt.figure(figsize=(8, 6))
sns.histplot(data=df_joined, x='meses_antiguedad', kde=True, color='green', stat='count', palette='Spectral')
plt.title('Distribución de los meses de antigüedad')
plt.xlabel('Meses de antigüedad')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=0)
plt.show()

# %%
# Suponiendo que tu columna de meses de antigüedad se llama 'months_antiquity'
df_joined['antiquity_category'] = pd.cut(df_joined['meses_antiguedad'],
                                bins=[0, 24, float('inf')],
                                labels=['Menos de 2 años', 'Más de 2 años'],
                                right=False)

# %%
# Grafico meses antiguedad
plt.figure(figsize=(8, 6))
sns.histplot(data=df_joined, x='antiquity_category',color='green', stat='count', palette='Spectral')
plt.title('Distribución de los meses de antigüedad')
plt.xlabel('Meses de antigüedad')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=0)
plt.show()

# %%
df_joined
# Out:
#        pk_cid gender  mes_partition       grupo_edad  median_salary  \
# 0     1200307      V              5  Adultos mayores    937,306.320
# 1      330599      H              5  Adultos mayores    314,597.850
# 2     1136531      H              5  Adultos jóvenes    236,739.840
# 3     1138692      V              5          Adultos    265,487.490
# 4     1258071      V              5          Adultos    714,033.300
# ...       ...    ...            ...              ...            ...
# 9995  1108774      H              5  Adultos jóvenes    154,672.140
# 9996  1298291      V              5          Adultos    129,719.160
# 9997  1209693      H              5  Adultos jóvenes     66,520.140
# 9998  1120992      H              5          Adultos    143,527.110
# 9999  1165902      H              5          Adultos    147,332.340
#
#      region_code entry_channel  active_customer             segment  \
# 0         Madrid           KFC                1   02 - PARTICULARES
# 1         Madrid           KFA                1   02 - PARTICULARES
# 2         Madrid           KAT                1   02 - PARTICULARES
# 3         Madrid           KFC                1   02 - PARTICULARES
# 4         Madrid           KFA                1   02 - PARTICULARES
# ...          ...           ...              ...                 ...
# 9995     Sevilla           KHE                1   02 - PARTICULARES
# 9996       Cádiz           KFC                1   02 - PARTICULARES
# 9997    Asturias           KFC                1  03 - UNIVERSITARIO
# 9998      Madrid           KAT                0   02 - PARTICULARES
# 9999      Madrid           KAT                0   02 - PARTICULARES
#
#       probability  age  meses_antiguedad antiquity_category
# 0           1.000   55                31      Más de 2 años
# 1           1.000   60                30      Más de 2 años
# 2           1.000   38                36      Más de 2 años
# 3           1.000   51                35      Más de 2 años
# 4           1.000   53                20    Menos de 2 años
# ...           ...  ...               ...                ...
# 9995        0.701   34                42      Más de 2 años
# 9996        0.701   51                21    Menos de 2 años
# 9997        0.701   30                31      Más de 2 años
# 9998        0.701   40                31      Más de 2 años
# 9999        0.701   47                33      Más de 2 años
#
# [10000 rows x 13 columns]

# %%
df_joined.drop('meses_antiguedad', axis=1 , inplace= True)

# %%
df_joined.drop('antiquity_category', axis=1 , inplace= True)

# %% [markdown]
# Convertimos la columna de meses de antigüedad en tres categorías: menos de un año, entre 1 y 3 años, y más de 3 años, con el objetivo de mejorar la segmentación de los datos.

# %% [markdown]
# ## Probabilidad de compra

# %%
# Supongamos que 'variable_numerica' es el nombre de tu columna numérica que va de 0 a 1
plt.figure(figsize=(8, 6))
sns.histplot(data=df_joined, x='probability', bins=30, color = "green" ,kde=True,stat='count', palette='Spectral')
plt.title('Distribución de la Probabilidad de compra')
plt.xlabel('Probababilidad de compra')
plt.ylabel('Numero de clientes')
plt.xlim(0.6, 1)
plt.xticks(rotation=0)
plt.show()

# %%
# Crear las categorías para 'probabilidad_compra' utilizando pd.cut
df_joined['categoria_probabilidad'] = pd.cut(df_joined['probability'],
                            bins=[0, 0.80, 0.90, 1.0],
                            labels=['Media', 'Alta', ' Muy Alta'],
                            right=True)

# %%
df_joined.drop('probability', axis=1, inplace=True)

# %% [markdown]
# Añadir la variable prob_compra a la segmentación tiene sentido porque proporciona una estimación clara de la probabilidad de que un cliente realice una compra. Con valores que van de 0.7 a 1, esta variable nos permite identificar distintos niveles de intención de compra. Al segmentar en función de esta probabilidad, podemos personalizar los mensajes de marketing, enfocándonos en aquellos clientes más propensos a realizar una compra y diferenciando estrategias para aquellos con probabilidades más bajas, lo que optimiza la efectividad de la campaña.

# %% [markdown]
# ## Edad

# %%
# Grafico edad
plt.figure(figsize=(8, 6))
sns.histplot(data=df_joined, x='age', bins=10, kde=True, color='green', stat='count', palette='Spectral')
plt.title('Distribución de la edad')
plt.xlabel('Edad')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=0)
plt.show()

# %%
percentile_33 = df_joined['age'].quantile(0.33)
percentile_70 = df_joined['age'].quantile(0.70)

print("Percentile 33:", percentile_33)
print("Percentile 70:", percentile_70)
# Out:
# Percentile 33: 36.0
# Percentile 70: 47.0

# %% [markdown]
# Convertir la edad numérica en categorías como "Jóvenes", "Adultos" y "Senior" mejora la segmentación al facilitar la identificación de patrones de comportamiento específicos para cada grupo etario. Además, permite diseñar estrategias de marketing personalizadas, simplifica el análisis y reduce el ruido en los datos, haciendo que las decisiones sean más claras y efectivas.

# %%
df_joined.drop('grupo_edad', axis=1, inplace=True)

# %%
# Categorías para 'age'
df_joined['age_category'] = pd.cut(df_joined['age'],
                            bins=[0, 36,48, float('inf')],
                            labels=['Jovenes/Adultos', 'Adultos', 'Senior'],
                            right=False)

# %%
# Grafico edad
plt.figure(figsize=(8, 6))
sns.histplot(data=df_joined, x='age_category', color='green', stat='count', palette='Spectral')
plt.title('Distribución de la edad')
plt.xlabel('Edad')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=0)
plt.show()

# %%
df_joined.drop('age', axis=1 , inplace= True)

# %% [markdown]
# ## Median_salary

# %%
# Grafico edad
plt.figure(figsize=(8, 6))
sns.histplot(data=df_joined, x='median_salary', bins=10, kde=True, color='green', stat='count', palette='Spectral')
plt.title('Distribución de la edad')
plt.xlabel('Edad')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=0)
plt.show()

# %%
df_joined['median_salary'].describe()
# Out:
# count       10,000.000
# mean       131,275.801
# std        208,609.944
# min         11,161.290
# 25%         70,479.668
# 50%         99,930.780
# 75%        144,895.312
# max     13,268,621.280
# Name: median_salary, dtype: float64

# %%
# Calcular los percentiles 90% y 95%
percentile_80 = df_joined['median_salary'].quantile(0.80)
percentile_90 = df_joined['median_salary'].quantile(0.90)

# Imprimir los resultados
print(f"Percentil 80: {percentile_80}")
print(f"Percentil 90: {percentile_90}")
# Out:
# Percentil 80: 161144.30400000006
# Percentil 90: 213372.744

# %%
df_joined['salary_segment'] = pd.cut(df_joined['median_salary'],
                            bins=[0, 85000, 130000,  float('inf')],
                            labels=['Salario bajo', 'Salario medio', 'Salario alto'],
                            right=False)

# %%
# Grafico edad
plt.figure(figsize=(8, 6))
sns.histplot(data=df_joined, x='salary_segment', color='green', stat='count', palette='Spectral')
plt.title('Distribución de la edad')
plt.xlabel('Edad')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=0)
plt.show()

# %%
df_joined.drop('median_salary', axis=1 , inplace= True)

# %%
df_joined.drop('mes_partition', axis=1 , inplace= True)

# %%
df_joined
# Out:
#        pk_cid gender region_code entry_channel  active_customer  \
# 0     1200307      V      Madrid           KFC                1
# 1      330599      H      Madrid           KFA                1
# 2     1136531      H      Madrid           KAT                1
# 3     1138692      V      Madrid           KFC                1
# 4     1258071      V      Madrid           KFA                1
# ...       ...    ...         ...           ...              ...
# 9995  1108774      H     Sevilla           KHE                1
# 9996  1298291      V       Cádiz           KFC                1
# 9997  1209693      H    Asturias           KFC                1
# 9998  1120992      H      Madrid           KAT                0
# 9999  1165902      H      Madrid           KAT                0
#
#                  segment categoria_probabilidad     age_category  \
# 0      02 - PARTICULARES               Muy Alta           Senior
# 1      02 - PARTICULARES               Muy Alta           Senior
# 2      02 - PARTICULARES               Muy Alta          Adultos
# 3      02 - PARTICULARES               Muy Alta           Senior
# 4      02 - PARTICULARES               Muy Alta           Senior
# ...                  ...                    ...              ...
# 9995   02 - PARTICULARES                  Media  Jovenes/Adultos
# 9996   02 - PARTICULARES                  Media           Senior
# 9997  03 - UNIVERSITARIO                  Media  Jovenes/Adultos
# 9998   02 - PARTICULARES                  Media          Adultos
# 9999   02 - PARTICULARES                  Media          Adultos
#
#      salary_segment
# 0      Salario alto
# 1      Salario alto
# 2      Salario alto
# 3      Salario alto
# 4      Salario alto
# ...             ...
# 9995   Salario alto
# 9996  Salario medio
# 9997   Salario bajo
# 9998   Salario alto
# 9999   Salario alto
#
# [10000 rows x 9 columns]

# %% [markdown]
# ## Numero de productos contratados

# %%
'''# Obtener los valores únicos de 'num_products_contracts'

plt.figure(figsize=(8, 6))
sns.countplot(data=df_joined, x='num_products_contracts', palette='Spectral')
plt.title('Distribución de Numero de Productos contratados')
plt.xlabel('Productos contratados')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=0)
plt.show()'''
# Out:
# "# Obtener los valores únicos de 'num_products_contracts'\n\nplt.figure(figsize=(8, 6))\nsns.countplot(data=df_joined, x='num_products_contracts', palette='Spectral')\nplt.title('Distribución de Numero de Productos contratados')\nplt.xlabel('Productos contratados')\nplt.ylabel('Numero de clientes')\nplt.xticks(rotation=0)\nplt.show()"

# %%
'''df_joined['num_products_contracts'].value_counts(normalize = True) * 100'''
# Out:
# "df_joined['num_products_contracts'].value_counts(normalize = True) * 100"

# %% [markdown]
# Se añade la variable num_products_contracts a la segmentación debido a su capacidad para proporcionar información valiosa sobre el comportamiento de los clientes. Con una distribución que muestra una variedad de niveles de contratación (desde 0 hasta 9 productos), esta variable permite identificar patrones en la lealtad del cliente y la potencialidad de ventas adicionales. Además, la inclusión de esta variable facilita la personalización de ofertas y la segmentación de clientes en función de su compromiso con la empresa, lo que puede conducir a estrategias de marketing más efectivas y a un aumento en la retención de clientes.

# %% [markdown]
# ## Gender

# %%
df_joined['gender'].value_counts(normalize = True) * 100
# Out:
# gender
# V   65.190
# H   34.810
# Name: proportion, dtype: float64

# %% [markdown]
# Se incluye la variable gender en la segmentación debido a su distribución un poco desequilibrada, con un 65.19% de hombres (V) y un 34.81% de mujeres (H). Esta diversidad permite identificar diferencias significativas en el comportamiento y las preferencias de los clientes, lo que es fundamental para personalizar las estrategias de marketing y mejorar la efectividad de las campañas dirigidas a cada género.

# %% [markdown]
# ## Mes_Partition

# %% [markdown]
# Se eliminan las variables mes_partition y mes_nombre_partition debido a su distribución desbalanceada, donde una única categoría (mes 5) .

# %% [markdown]
# ## Active_customer

# %%
df_joined['active_customer'].value_counts(normalize = True) * 100
# Out:
# active_customer
# 1   97.230
# 0    2.770
# Name: proportion, dtype: float64

# %% [markdown]
# Se elimina esta variabel por no proporcionar demasiada informacion.

# %%
df_joined.drop('active_customer', axis = 1, inplace=True)

# %%
df_joined
# Out:
#        pk_cid gender region_code entry_channel             segment  \
# 0     1200307      V      Madrid           KFC   02 - PARTICULARES
# 1      330599      H      Madrid           KFA   02 - PARTICULARES
# 2     1136531      H      Madrid           KAT   02 - PARTICULARES
# 3     1138692      V      Madrid           KFC   02 - PARTICULARES
# 4     1258071      V      Madrid           KFA   02 - PARTICULARES
# ...       ...    ...         ...           ...                 ...
# 9995  1108774      H     Sevilla           KHE   02 - PARTICULARES
# 9996  1298291      V       Cádiz           KFC   02 - PARTICULARES
# 9997  1209693      H    Asturias           KFC  03 - UNIVERSITARIO
# 9998  1120992      H      Madrid           KAT   02 - PARTICULARES
# 9999  1165902      H      Madrid           KAT   02 - PARTICULARES
#
#      categoria_probabilidad     age_category salary_segment
# 0                  Muy Alta           Senior   Salario alto
# 1                  Muy Alta           Senior   Salario alto
# 2                  Muy Alta          Adultos   Salario alto
# 3                  Muy Alta           Senior   Salario alto
# 4                  Muy Alta           Senior   Salario alto
# ...                     ...              ...            ...
# 9995                  Media  Jovenes/Adultos   Salario alto
# 9996                  Media           Senior  Salario medio
# 9997                  Media  Jovenes/Adultos   Salario bajo
# 9998                  Media          Adultos   Salario alto
# 9999                  Media          Adultos   Salario alto
#
# [10000 rows x 8 columns]

# %% [markdown]
# ## Segment

# %%
df_joined['segment'].value_counts(normalize = True) * 100
# Out:
# segment
# 02 - PARTICULARES    74.570
# 03 - UNIVERSITARIO   15.070
# 01 - TOP             10.360
# Name: proportion, dtype: float64

# %% [markdown]
# ## Region_code

# %%
plt.figure(figsize=(12, 4))
sns.histplot(data=df_joined, x='region_code', kde=True, color='green', palette='Spectral')
plt.title('Distribución de clientes por ciudad')
plt.xlabel('Provincias')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=90)
plt.show()

# %%
df_joined['region_code'].value_counts(normalize = True) * 100
# Out:
# region_code
# Madrid                   44.170
# Barcelona                 6.620
# Valencia                  5.610
# Alicante                  3.660
# Sevilla                   3.320
# Málaga                    2.020
# Granada                   2.010
# Palmas, Las               2.010
# Coruña, A                 1.750
# Cantabria                 1.580
# Pontevedra                1.490
# Asturias                  1.490
# Murcia                    1.440
# Cádiz                     1.430
# Baleares, Islas           1.420
# Zaragoza                  1.320
# Valladolid                1.250
# Toledo                    1.170
# Castellón                 1.030
# Bizkaia                   1.020
# Santa Cruz de Tenerife    0.990
# Almería                   0.930
# Badajoz                   0.750
# Burgos                    0.720
# Jaén                      0.710
# Salamanca                 0.710
# Gipuzkoa                  0.640
# Guadalajara               0.630
# Huelva                    0.620
# Ciudad Real               0.610
# Córdoba                   0.610
# Albacete                  0.600
# Rioja, La                 0.580
# Cáceres                   0.490
# Tarragona                 0.470
# León                      0.450
# Girona                    0.420
# Navarra                   0.410
# Lugo                      0.410
# Ourense                   0.380
# Álava                     0.320
# Ávila                     0.260
# Huesca                    0.240
# Segovia                   0.240
# Lleida                    0.210
# Zamora                    0.210
# Cuenca                    0.200
# Palencia                  0.110
# Extranjero                0.090
# Ceuta                     0.070
# Soria                     0.040
# Teruel                    0.040
# Melilla                   0.030
# Name: proportion, dtype: float64

# %% [markdown]
# Voy a sustituir cada provincia por su número de habitantes para calcular la media de habitantes en cada cluster, lo que me brindará una idea del tamaño de las ciudades de mis clientes. Aunque no podré identificar la región específica de cada segmento, esta información me ayudará a diferenciar entre clientes de ciudades grandes y pequeñas.
#
# Para llevar a cabo este enfoque, recogeré los datos de población del INE del año 2019 y realizaré las sustituciones necesarias.

# %%
# Población total de España
poblacion_total = 47026208

# Calcular la media de población por provincia
media_poblacion = poblacion_total / 52

# Diccionario que relaciona las provincias con su población
poblacion_dict = {
    'Madrid': 6663394,
    'Asturias': 1022800,
    'Palmas, Las': 1120406,
    'Barcelona': 5664579,
    'Valencia': 2565124,
    'Coruña, A': 1119596,
    'Sevilla': 1942389,
    'Alicante': 1858683,
    'Zaragoza': 964693,
    'Pontevedra': 942665,
    'Murcia': 1493898,
    'Cádiz': 1240155,
    'Valladolid': 519546,
    'Málaga': 1661785,
    'Salamanca': 330119,
    'Cantabria': 581078,
    'Bizkaia': 1152651,
    'Ávila': 157640,
    'Cáceres': 394151,
    'Toledo': 694844,
    'Burgos': 356958,
    'Albacete': 388167,
    'Baleares, Islas': 1149460,
    'Córdoba': 782979,
    'Granada': 914678,
    'Rioja, La': 316798,
    'Badajoz': 673559,
    'Castellón': 579962,
    'Lugo': 329587,
    'Ciudad Real': 495761,
    'Ourense': 307651,
    'León': 460001,
    'Huelva': 521870,
    'Jaén': 633564,
    'Tarragona': 804664,
    'Santa Cruz de Tenerife': 1032983,
    'Navarra': 654214,
    'Zamora': 172539,
    'Álava': 331549,
    'Almería': 716820,
    'Gipuzkoa': 723576,
    'Palencia': 160980,
    'Guadalajara': 257762,
    'Segovia': 153129,
    'Girona': 771044,
    'Cuenca': 196329,
    'Huesca': 220461,
    'Lleida': 434930,
    'Extranjero': media_poblacion,  # Media de la población para "Extranjero"
    'Soria': 88636,
    'Teruel': 134137,
    'Melilla': 86487,
    'Ceuta': 84777
}

# Reemplazar los nombres de provincias en df_joined por la población correspondiente
df_joined['region_code'] = df_joined['region_code'].replace(poblacion_dict)

# Cambiar el tipo de la columna a int
df_joined['region_code'] = df_joined['region_code'].astype(int)

# Verifica los cambios
df_joined
# Out:
#        pk_cid gender  region_code entry_channel             segment  \
# 0     1200307      V      6663394           KFC   02 - PARTICULARES
# 1      330599      H      6663394           KFA   02 - PARTICULARES
# 2     1136531      H      6663394           KAT   02 - PARTICULARES
# 3     1138692      V      6663394           KFC   02 - PARTICULARES
# 4     1258071      V      6663394           KFA   02 - PARTICULARES
# ...       ...    ...          ...           ...                 ...
# 9995  1108774      H      1942389           KHE   02 - PARTICULARES
# 9996  1298291      V      1240155           KFC   02 - PARTICULARES
# 9997  1209693      H      1022800           KFC  03 - UNIVERSITARIO
# 9998  1120992      H      6663394           KAT   02 - PARTICULARES
# 9999  1165902      H      6663394           KAT   02 - PARTICULARES
#
#      categoria_probabilidad     age_category salary_segment
# 0                  Muy Alta           Senior   Salario alto
# 1                  Muy Alta           Senior   Salario alto
# 2                  Muy Alta          Adultos   Salario alto
# 3                  Muy Alta           Senior   Salario alto
# 4                  Muy Alta           Senior   Salario alto
# ...                     ...              ...            ...
# 9995                  Media  Jovenes/Adultos   Salario alto
# 9996                  Media           Senior  Salario medio
# 9997                  Media  Jovenes/Adultos   Salario bajo
# 9998                  Media          Adultos   Salario alto
# 9999                  Media          Adultos   Salario alto
#
# [10000 rows x 8 columns]

# %%
plt.figure(figsize=(12, 4))
sns.histplot(data=df_joined, x='region_code', kde=True, color='green', palette='Spectral')
plt.title('Distribución de clientes por ciudad')
plt.xlabel('Provincias')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=90)
plt.show()

# %%
df_joined['region_code'].describe()
# Out:
# count      10,000.000
# mean    3,902,064.243
# std     2,728,339.859
# min        84,777.000
# 25%     1,032,983.000
# 50%     5,664,579.000
# 75%     6,663,394.000
# max     6,663,394.000
# Name: region_code, dtype: float64

# %%
df_joined['city_size'] = pd.cut(df_joined['region_code'],
                        bins=[0,1000000, 3000000, float('inf')],
                        labels=['Ciudad pequeña',"Ciudad Media" ,'Gran ciudad'],
                        right=False)

# %%
df_joined
# Out:
#        pk_cid gender  region_code entry_channel             segment  \
# 0     1200307      V      6663394           KFC   02 - PARTICULARES
# 1      330599      H      6663394           KFA   02 - PARTICULARES
# 2     1136531      H      6663394           KAT   02 - PARTICULARES
# 3     1138692      V      6663394           KFC   02 - PARTICULARES
# 4     1258071      V      6663394           KFA   02 - PARTICULARES
# ...       ...    ...          ...           ...                 ...
# 9995  1108774      H      1942389           KHE   02 - PARTICULARES
# 9996  1298291      V      1240155           KFC   02 - PARTICULARES
# 9997  1209693      H      1022800           KFC  03 - UNIVERSITARIO
# 9998  1120992      H      6663394           KAT   02 - PARTICULARES
# 9999  1165902      H      6663394           KAT   02 - PARTICULARES
#
#      categoria_probabilidad     age_category salary_segment     city_size
# 0                  Muy Alta           Senior   Salario alto   Gran ciudad
# 1                  Muy Alta           Senior   Salario alto   Gran ciudad
# 2                  Muy Alta          Adultos   Salario alto   Gran ciudad
# 3                  Muy Alta           Senior   Salario alto   Gran ciudad
# 4                  Muy Alta           Senior   Salario alto   Gran ciudad
# ...                     ...              ...            ...           ...
# 9995                  Media  Jovenes/Adultos   Salario alto  Ciudad Media
# 9996                  Media           Senior  Salario medio  Ciudad Media
# 9997                  Media  Jovenes/Adultos   Salario bajo  Ciudad Media
# 9998                  Media          Adultos   Salario alto   Gran ciudad
# 9999                  Media          Adultos   Salario alto   Gran ciudad
#
# [10000 rows x 9 columns]

# %%
df_joined.drop('region_code', axis=1, inplace=True)

# %% [markdown]
# La columna entry_channel se eliminará del DataFrame debido a la falta de información sobre su significado y contexto. Sin una comprensión clara de lo que representa, es difícil evaluar su relevancia y utilidad en el análisis

# %%
df_joined.drop('entry_channel', axis=1, inplace=True)

# %%
df_joined
# Out:
#        pk_cid gender             segment categoria_probabilidad  \
# 0     1200307      V   02 - PARTICULARES               Muy Alta
# 1      330599      H   02 - PARTICULARES               Muy Alta
# 2     1136531      H   02 - PARTICULARES               Muy Alta
# 3     1138692      V   02 - PARTICULARES               Muy Alta
# 4     1258071      V   02 - PARTICULARES               Muy Alta
# ...       ...    ...                 ...                    ...
# 9995  1108774      H   02 - PARTICULARES                  Media
# 9996  1298291      V   02 - PARTICULARES                  Media
# 9997  1209693      H  03 - UNIVERSITARIO                  Media
# 9998  1120992      H   02 - PARTICULARES                  Media
# 9999  1165902      H   02 - PARTICULARES                  Media
#
#          age_category salary_segment     city_size
# 0              Senior   Salario alto   Gran ciudad
# 1              Senior   Salario alto   Gran ciudad
# 2             Adultos   Salario alto   Gran ciudad
# 3              Senior   Salario alto   Gran ciudad
# 4              Senior   Salario alto   Gran ciudad
# ...               ...            ...           ...
# 9995  Jovenes/Adultos   Salario alto  Ciudad Media
# 9996           Senior  Salario medio  Ciudad Media
# 9997  Jovenes/Adultos   Salario bajo  Ciudad Media
# 9998          Adultos   Salario alto   Gran ciudad
# 9999          Adultos   Salario alto   Gran ciudad
#
# [10000 rows x 7 columns]

# %%
plt.figure(figsize=(12, 4))
sns.histplot(data=df_joined, x='city_size', color='green', palette='Spectral')
plt.title('Distribución de clientes por ciudad')
plt.xlabel('Provincias')
plt.ylabel('Numero de clientes')
plt.xticks(rotation=90)
plt.show()

# %%
df_joined
# Out:
#        pk_cid gender             segment categoria_probabilidad  \
# 0     1200307      V   02 - PARTICULARES               Muy Alta
# 1      330599      H   02 - PARTICULARES               Muy Alta
# 2     1136531      H   02 - PARTICULARES               Muy Alta
# 3     1138692      V   02 - PARTICULARES               Muy Alta
# 4     1258071      V   02 - PARTICULARES               Muy Alta
# ...       ...    ...                 ...                    ...
# 9995  1108774      H   02 - PARTICULARES                  Media
# 9996  1298291      V   02 - PARTICULARES                  Media
# 9997  1209693      H  03 - UNIVERSITARIO                  Media
# 9998  1120992      H   02 - PARTICULARES                  Media
# 9999  1165902      H   02 - PARTICULARES                  Media
#
#          age_category salary_segment     city_size
# 0              Senior   Salario alto   Gran ciudad
# 1              Senior   Salario alto   Gran ciudad
# 2             Adultos   Salario alto   Gran ciudad
# 3              Senior   Salario alto   Gran ciudad
# 4              Senior   Salario alto   Gran ciudad
# ...               ...            ...           ...
# 9995  Jovenes/Adultos   Salario alto  Ciudad Media
# 9996           Senior  Salario medio  Ciudad Media
# 9997  Jovenes/Adultos   Salario bajo  Ciudad Media
# 9998          Adultos   Salario alto   Gran ciudad
# 9999          Adultos   Salario alto   Gran ciudad
#
# [10000 rows x 7 columns]

# %% [markdown]
# # Encoding

# %%
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pk_cid                  10000 non-null  int64
#  1   gender                  10000 non-null  object
#  2   segment                 10000 non-null  category
#  3   categoria_probabilidad  10000 non-null  category
#  4   age_category            10000 non-null  category
#  5   salary_segment          10000 non-null  category
#  6   city_size               10000 non-null  category
# dtypes: category(5), int64(1), object(1)
# memory usage: 205.9+ KB

# %%
df_joined_1 = df_joined.copy()

# %%
# Cambiar 'gender' a 1 si es 'V' y 0 si es 'H'
df_joined['genero_v'] = df_joined['gender'].map({'V': 1, 'H': 0})

# Eliminar la columna original 'gender'
df_joined.drop(columns=['gender'], inplace=True)

# %%
df_joined
# Out:
#        pk_cid             segment categoria_probabilidad     age_category  \
# 0     1200307   02 - PARTICULARES               Muy Alta           Senior
# 1      330599   02 - PARTICULARES               Muy Alta           Senior
# 2     1136531   02 - PARTICULARES               Muy Alta          Adultos
# 3     1138692   02 - PARTICULARES               Muy Alta           Senior
# 4     1258071   02 - PARTICULARES               Muy Alta           Senior
# ...       ...                 ...                    ...              ...
# 9995  1108774   02 - PARTICULARES                  Media  Jovenes/Adultos
# 9996  1298291   02 - PARTICULARES                  Media           Senior
# 9997  1209693  03 - UNIVERSITARIO                  Media  Jovenes/Adultos
# 9998  1120992   02 - PARTICULARES                  Media          Adultos
# 9999  1165902   02 - PARTICULARES                  Media          Adultos
#
#      salary_segment     city_size  genero_v
# 0      Salario alto   Gran ciudad         1
# 1      Salario alto   Gran ciudad         0
# 2      Salario alto   Gran ciudad         0
# 3      Salario alto   Gran ciudad         1
# 4      Salario alto   Gran ciudad         1
# ...             ...           ...       ...
# 9995   Salario alto  Ciudad Media         0
# 9996  Salario medio  Ciudad Media         1
# 9997   Salario bajo  Ciudad Media         0
# 9998   Salario alto   Gran ciudad         0
# 9999   Salario alto   Gran ciudad         0
#
# [10000 rows x 7 columns]

# %%
df_joined.set_index('pk_cid', inplace=True)

# %%
df_joined
# Out:
#                     segment categoria_probabilidad     age_category  \
# pk_cid
# 1200307   02 - PARTICULARES               Muy Alta           Senior
# 330599    02 - PARTICULARES               Muy Alta           Senior
# 1136531   02 - PARTICULARES               Muy Alta          Adultos
# 1138692   02 - PARTICULARES               Muy Alta           Senior
# 1258071   02 - PARTICULARES               Muy Alta           Senior
# ...                     ...                    ...              ...
# 1108774   02 - PARTICULARES                  Media  Jovenes/Adultos
# 1298291   02 - PARTICULARES                  Media           Senior
# 1209693  03 - UNIVERSITARIO                  Media  Jovenes/Adultos
# 1120992   02 - PARTICULARES                  Media          Adultos
# 1165902   02 - PARTICULARES                  Media          Adultos
#
#         salary_segment     city_size  genero_v
# pk_cid
# 1200307   Salario alto   Gran ciudad         1
# 330599    Salario alto   Gran ciudad         0
# 1136531   Salario alto   Gran ciudad         0
# 1138692   Salario alto   Gran ciudad         1
# 1258071   Salario alto   Gran ciudad         1
# ...                ...           ...       ...
# 1108774   Salario alto  Ciudad Media         0
# 1298291  Salario medio  Ciudad Media         1
# 1209693   Salario bajo  Ciudad Media         0
# 1120992   Salario alto   Gran ciudad         0
# 1165902   Salario alto   Gran ciudad         0
#
# [10000 rows x 6 columns]

# %%
df_joined
# Out:
#                     segment categoria_probabilidad     age_category  \
# pk_cid
# 1200307   02 - PARTICULARES               Muy Alta           Senior
# 330599    02 - PARTICULARES               Muy Alta           Senior
# 1136531   02 - PARTICULARES               Muy Alta          Adultos
# 1138692   02 - PARTICULARES               Muy Alta           Senior
# 1258071   02 - PARTICULARES               Muy Alta           Senior
# ...                     ...                    ...              ...
# 1108774   02 - PARTICULARES                  Media  Jovenes/Adultos
# 1298291   02 - PARTICULARES                  Media           Senior
# 1209693  03 - UNIVERSITARIO                  Media  Jovenes/Adultos
# 1120992   02 - PARTICULARES                  Media          Adultos
# 1165902   02 - PARTICULARES                  Media          Adultos
#
#         salary_segment     city_size  genero_v
# pk_cid
# 1200307   Salario alto   Gran ciudad         1
# 330599    Salario alto   Gran ciudad         0
# 1136531   Salario alto   Gran ciudad         0
# 1138692   Salario alto   Gran ciudad         1
# 1258071   Salario alto   Gran ciudad         1
# ...                ...           ...       ...
# 1108774   Salario alto  Ciudad Media         0
# 1298291  Salario medio  Ciudad Media         1
# 1209693   Salario bajo  Ciudad Media         0
# 1120992   Salario alto   Gran ciudad         0
# 1165902   Salario alto   Gran ciudad         0
#
# [10000 rows x 6 columns]

# %%
df_joined.drop('segment', axis=1, inplace=True)

# %%
df_joined
# Out:
#         categoria_probabilidad     age_category salary_segment     city_size  \
# pk_cid
# 1200307               Muy Alta           Senior   Salario alto   Gran ciudad
# 330599                Muy Alta           Senior   Salario alto   Gran ciudad
# 1136531               Muy Alta          Adultos   Salario alto   Gran ciudad
# 1138692               Muy Alta           Senior   Salario alto   Gran ciudad
# 1258071               Muy Alta           Senior   Salario alto   Gran ciudad
# ...                        ...              ...            ...           ...
# 1108774                  Media  Jovenes/Adultos   Salario alto  Ciudad Media
# 1298291                  Media           Senior  Salario medio  Ciudad Media
# 1209693                  Media  Jovenes/Adultos   Salario bajo  Ciudad Media
# 1120992                  Media          Adultos   Salario alto   Gran ciudad
# 1165902                  Media          Adultos   Salario alto   Gran ciudad
#
#          genero_v
# pk_cid
# 1200307         1
# 330599          0
# 1136531         0
# 1138692         1
# 1258071         1
# ...           ...
# 1108774         0
# 1298291         1
# 1209693         0
# 1120992         0
# 1165902         0
#
# [10000 rows x 5 columns]

# %%
# Aplicar get_dummies a las columnas 'recomendacion' y 'segment'
df_joined = pd.get_dummies(df_joined, columns=['categoria_probabilidad','age_category','salary_segment','city_size'], dtype=int)

# %%
# Calculamos la matriz de correlación
correlation_matrix = df_joined.corr()

# Configuramos el tamaño del gráfico
plt.figure(figsize=(12, 12))

# Creamos el mapa de calor
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar=True, linewidths=0.5)

# Título del gráfico
plt.title('Mapa de Correlaciones de Variables Numéricas')

# Mostramos el gráfico
plt.show()

# %%
df_joined
# Out:
#          genero_v  categoria_probabilidad_Media  categoria_probabilidad_Alta  \
# pk_cid
# 1200307         1                             0                            0
# 330599          0                             0                            0
# 1136531         0                             0                            0
# 1138692         1                             0                            0
# 1258071         1                             0                            0
# ...           ...                           ...                          ...
# 1108774         0                             1                            0
# 1298291         1                             1                            0
# 1209693         0                             1                            0
# 1120992         0                             1                            0
# 1165902         0                             1                            0
#
#          categoria_probabilidad_ Muy Alta  age_category_Jovenes/Adultos  \
# pk_cid
# 1200307                                 1                             0
# 330599                                  1                             0
# 1136531                                 1                             0
# 1138692                                 1                             0
# 1258071                                 1                             0
# ...                                   ...                           ...
# 1108774                                 0                             1
# 1298291                                 0                             0
# 1209693                                 0                             1
# 1120992                                 0                             0
# 1165902                                 0                             0
#
#          age_category_Adultos  age_category_Senior  \
# pk_cid
# 1200307                     0                    1
# 330599                      0                    1
# 1136531                     1                    0
# 1138692                     0                    1
# 1258071                     0                    1
# ...                       ...                  ...
# 1108774                     0                    0
# 1298291                     0                    1
# 1209693                     0                    0
# 1120992                     1                    0
# 1165902                     1                    0
#
#          salary_segment_Salario bajo  salary_segment_Salario medio  \
# pk_cid
# 1200307                            0                             0
# 330599                             0                             0
# 1136531                            0                             0
# 1138692                            0                             0
# 1258071                            0                             0
# ...                              ...                           ...
# 1108774                            0                             0
# 1298291                            0                             1
# 1209693                            1                             0
# 1120992                            0                             0
# 1165902                            0                             0
#
#          salary_segment_Salario alto  city_size_Ciudad pequeña  \
# pk_cid
# 1200307                            1                         0
# 330599                             1                         0
# 1136531                            1                         0
# 1138692                            1                         0
# 1258071                            1                         0
# ...                              ...                       ...
# 1108774                            1                         0
# 1298291                            0                         0
# 1209693                            0                         0
# 1120992                            1                         0
# 1165902                            1                         0
#
#          city_size_Ciudad Media  city_size_Gran ciudad
# pk_cid
# 1200307                       0                      1
# 330599                        0                      1
# 1136531                       0                      1
# 1138692                       0                      1
# 1258071                       0                      1
# ...                         ...                    ...
# 1108774                       1                      0
# 1298291                       1                      0
# 1209693                       1                      0
# 1120992                       0                      1
# 1165902                       0                      1
#
# [10000 rows x 13 columns]

# %%
'''# Crear el escalador
scaler = RobustScaler()

# Aplicar el escalador a las columnas numéricas
df_joined_scaled = df_joined.copy()
df_joined_scaled[df_joined_scaled.columns] = scaler.fit_transform(df_joined_scaled)

# Mostrar el DataFrame escalado
df_joined_scaled'''
# Out:
# '# Crear el escalador\nscaler = RobustScaler()\n\n# Aplicar el escalador a las columnas numéricas\ndf_joined_scaled = df_joined.copy()\ndf_joined_scaled[df_joined_scaled.columns] = scaler.fit_transform(df_joined_scaled)\n\n# Mostrar el DataFrame escalado\ndf_joined_scaled'

# %%
# Definir el rango de clusters a evaluar
range_n_clusters = range(1, 20)
inertia = []

# Calcular la inercia para cada número de clusters
for k in range_n_clusters:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_joined)
    inertia.append(kmeans.inertia_)

# Dibujar la curva del codo
plt.figure(figsize=(8, 6))
sns.lineplot(x=range_n_clusters, y=inertia, marker='o',color = 'green',palette='Spectral')
plt.title('Curva del Codo para el Número Óptimo de Clusters')
plt.xlabel('Número de Clusters (K)')
plt.ylabel('Inercia')
plt.xticks(range_n_clusters)
plt.grid()
plt.show()

# %%
cluster_model_4 = KMeans(n_clusters = 4, random_state=42)
cluster_model_5 = KMeans(n_clusters = 5, random_state=42)
cluster_model_6 = KMeans(n_clusters = 6, random_state=42)


df_joined['cluster_4'] = cluster_model_4.fit_predict(df_joined)
df_joined['cluster_5'] = cluster_model_5.fit_predict(df_joined)
df_joined['cluster_6'] = cluster_model_6.fit_predict(df_joined)


print(df_joined['cluster_4'].value_counts())
print(df_joined['cluster_5'].value_counts())
print(df_joined['cluster_6'].value_counts())
# Out:
# cluster_4
# 3    2973
# 2    2675
# 0    2472
# 1    1880
# Name: count, dtype: int64
# cluster_5
# 2    2675
# 0    2472
# 3    1880
# 1    1688
# 4    1285
# Name: count, dtype: int64
# cluster_6
# 0    2472
# 1    1880
# 3    1688
# 5    1554
# 4    1285
# 2    1121
# Name: count, dtype: int64

# %%
df_joined_scaled_4 = df_joined.drop('cluster_5', axis=1)

# %%
df_joined_scaled_5 = df_joined.drop('cluster_4', axis=1)

# %%
df_joined_scaled_6 = df_joined.drop('cluster_5', axis=1)

# %%
df_joined_scaled_4
# Out:
#          genero_v  categoria_probabilidad_Media  categoria_probabilidad_Alta  \
# pk_cid
# 1200307         1                             0                            0
# 330599          0                             0                            0
# 1136531         0                             0                            0
# 1138692         1                             0                            0
# 1258071         1                             0                            0
# ...           ...                           ...                          ...
# 1108774         0                             1                            0
# 1298291         1                             1                            0
# 1209693         0                             1                            0
# 1120992         0                             1                            0
# 1165902         0                             1                            0
#
#          categoria_probabilidad_ Muy Alta  age_category_Jovenes/Adultos  \
# pk_cid
# 1200307                                 1                             0
# 330599                                  1                             0
# 1136531                                 1                             0
# 1138692                                 1                             0
# 1258071                                 1                             0
# ...                                   ...                           ...
# 1108774                                 0                             1
# 1298291                                 0                             0
# 1209693                                 0                             1
# 1120992                                 0                             0
# 1165902                                 0                             0
#
#          age_category_Adultos  age_category_Senior  \
# pk_cid
# 1200307                     0                    1
# 330599                      0                    1
# 1136531                     1                    0
# 1138692                     0                    1
# 1258071                     0                    1
# ...                       ...                  ...
# 1108774                     0                    0
# 1298291                     0                    1
# 1209693                     0                    0
# 1120992                     1                    0
# 1165902                     1                    0
#
#          salary_segment_Salario bajo  salary_segment_Salario medio  \
# pk_cid
# 1200307                            0                             0
# 330599                             0                             0
# 1136531                            0                             0
# 1138692                            0                             0
# 1258071                            0                             0
# ...                              ...                           ...
# 1108774                            0                             0
# 1298291                            0                             1
# 1209693                            1                             0
# 1120992                            0                             0
# 1165902                            0                             0
#
#          salary_segment_Salario alto  city_size_Ciudad pequeña  \
# pk_cid
# 1200307                            1                         0
# 330599                             1                         0
# 1136531                            1                         0
# 1138692                            1                         0
# 1258071                            1                         0
# ...                              ...                       ...
# 1108774                            1                         0
# 1298291                            0                         0
# 1209693                            0                         0
# 1120992                            1                         0
# 1165902                            1                         0
#
#          city_size_Ciudad Media  city_size_Gran ciudad  cluster_4  cluster_6
# pk_cid
# 1200307                       0                      1          3          3
# 330599                        0                      1          3          3
# 1136531                       0                      1          3          4
# 1138692                       0                      1          3          3
# 1258071                       0                      1          3          3
# ...                         ...                    ...        ...        ...
# 1108774                       1                      0          1          1
# 1298291                       1                      0          1          1
# 1209693                       1                      0          0          0
# 1120992                       0                      1          3          4
# 1165902                       0                      1          3          4
#
# [10000 rows x 15 columns]

# %%
df_joined_scaled_5
# Out:
#          genero_v  categoria_probabilidad_Media  categoria_probabilidad_Alta  \
# pk_cid
# 1200307         1                             0                            0
# 330599          0                             0                            0
# 1136531         0                             0                            0
# 1138692         1                             0                            0
# 1258071         1                             0                            0
# ...           ...                           ...                          ...
# 1108774         0                             1                            0
# 1298291         1                             1                            0
# 1209693         0                             1                            0
# 1120992         0                             1                            0
# 1165902         0                             1                            0
#
#          categoria_probabilidad_ Muy Alta  age_category_Jovenes/Adultos  \
# pk_cid
# 1200307                                 1                             0
# 330599                                  1                             0
# 1136531                                 1                             0
# 1138692                                 1                             0
# 1258071                                 1                             0
# ...                                   ...                           ...
# 1108774                                 0                             1
# 1298291                                 0                             0
# 1209693                                 0                             1
# 1120992                                 0                             0
# 1165902                                 0                             0
#
#          age_category_Adultos  age_category_Senior  \
# pk_cid
# 1200307                     0                    1
# 330599                      0                    1
# 1136531                     1                    0
# 1138692                     0                    1
# 1258071                     0                    1
# ...                       ...                  ...
# 1108774                     0                    0
# 1298291                     0                    1
# 1209693                     0                    0
# 1120992                     1                    0
# 1165902                     1                    0
#
#          salary_segment_Salario bajo  salary_segment_Salario medio  \
# pk_cid
# 1200307                            0                             0
# 330599                             0                             0
# 1136531                            0                             0
# 1138692                            0                             0
# 1258071                            0                             0
# ...                              ...                           ...
# 1108774                            0                             0
# 1298291                            0                             1
# 1209693                            1                             0
# 1120992                            0                             0
# 1165902                            0                             0
#
#          salary_segment_Salario alto  city_size_Ciudad pequeña  \
# pk_cid
# 1200307                            1                         0
# 330599                             1                         0
# 1136531                            1                         0
# 1138692                            1                         0
# 1258071                            1                         0
# ...                              ...                       ...
# 1108774                            1                         0
# 1298291                            0                         0
# 1209693                            0                         0
# 1120992                            1                         0
# 1165902                            1                         0
#
#          city_size_Ciudad Media  city_size_Gran ciudad  cluster_5  cluster_6
# pk_cid
# 1200307                       0                      1          1          3
# 330599                        0                      1          1          3
# 1136531                       0                      1          4          4
# 1138692                       0                      1          1          3
# 1258071                       0                      1          1          3
# ...                         ...                    ...        ...        ...
# 1108774                       1                      0          3          1
# 1298291                       1                      0          3          1
# 1209693                       1                      0          0          0
# 1120992                       0                      1          4          4
# 1165902                       0                      1          4          4
#
# [10000 rows x 15 columns]

# %%
cols = list(df_joined_scaled_5.columns)
cols.remove("cluster_5")
# Calcular las medias para cada cluster
pt = pd.pivot_table(df_joined_scaled_5, index='cluster_5', values=cols, aggfunc='mean')

# Calcular la cantidad de elementos en cada cluster
add = pd.pivot_table(df_joined_scaled_5, index='cluster_5', values='genero_v', aggfunc='count')
pt['count'] = add

# Añadir 'count' a la lista de columnas para la visualización final
cols.append('count')

# Mostrar la tabla con estilos y gradientes de color
pt[cols].style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0f870_row0_col0, #T_0f870_row0_col7, #T_0f870_row0_col11, #T_0f870_row1_col3, #T_0f870_row1_col6, #T_0f870_row1_col9, #T_0f870_row1_col12, #T_0f870_row2_col2, #T_0f870_row2_col14, #T_0f870_row3_col1, #T_0f870_row3_col4, #T_0f870_row3_col8, #T_0f870_row3_col10, #T_0f870_row4_col5, #T_0f870_row4_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0f870_row0_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_0f870_row0_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_0f870_row0_col3, #T_0f870_row2_col8 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_0f870_row0_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_0f870_row0_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_0f870_row0_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_0f870_row0_col8, #T_0f870_row0_col9, #T_0f870_row0_col12, #T_0f870_row0_col13, #T_0f870_row1_col0, #T_0f870_row1_col2, #T_0f870_row1_col5, #T_0f870_row1_col7, #T_0f870_row1_col10, #T_0f870_row1_col11, #T_0f870_row2_col1, #T_0f870_row2_col3, #T_0f870_row3_col2, #T_0f870_row4_col2, #T_0f870_row4_col4, #T_0f870_row4_col6, #T_0f870_row4_col11, #T_0f870_row4_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0f870_row0_col10 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_0f870_row0_col14 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_0f870_row1_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_0f870_row1_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_0f870_row1_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_0f870_row1_col13 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_0f870_row1_col14 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_0f870_row2_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_0f870_row2_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_0f870_row2_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_0f870_row2_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_0f870_row2_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_0f870_row2_col9 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_0f870_row2_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_0f870_row2_col11 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_0f870_row2_col12 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_0f870_row2_col13 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_0f870_row3_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_0f870_row3_col3 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_0f870_row3_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_0f870_row3_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_0f870_row3_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_0f870_row3_col9 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_0f870_row3_col11 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_0f870_row3_col12, #T_0f870_row3_col13 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_0f870_row3_col14 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_0f870_row4_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_0f870_row4_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_0f870_row4_col3 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_0f870_row4_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_0f870_row4_col8 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_0f870_row4_col9 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_0f870_row4_col10 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_0f870_row4_col12 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0f870">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f870_level0_col0" class="col_heading level0 col0" >genero_v</th>
#       <th id="T_0f870_level0_col1" class="col_heading level0 col1" >categoria_probabilidad_Media</th>
#       <th id="T_0f870_level0_col2" class="col_heading level0 col2" >categoria_probabilidad_Alta</th>
#       <th id="T_0f870_level0_col3" class="col_heading level0 col3" >categoria_probabilidad_ Muy Alta</th>
#       <th id="T_0f870_level0_col4" class="col_heading level0 col4" >age_category_Jovenes/Adultos</th>
#       <th id="T_0f870_level0_col5" class="col_heading level0 col5" >age_category_Adultos</th>
#       <th id="T_0f870_level0_col6" class="col_heading level0 col6" >age_category_Senior</th>
#       <th id="T_0f870_level0_col7" class="col_heading level0 col7" >salary_segment_Salario bajo</th>
#       <th id="T_0f870_level0_col8" class="col_heading level0 col8" >salary_segment_Salario medio</th>
#       <th id="T_0f870_level0_col9" class="col_heading level0 col9" >salary_segment_Salario alto</th>
#       <th id="T_0f870_level0_col10" class="col_heading level0 col10" >city_size_Ciudad pequeña</th>
#       <th id="T_0f870_level0_col11" class="col_heading level0 col11" >city_size_Ciudad Media</th>
#       <th id="T_0f870_level0_col12" class="col_heading level0 col12" >city_size_Gran ciudad</th>
#       <th id="T_0f870_level0_col13" class="col_heading level0 col13" >cluster_6</th>
#       <th id="T_0f870_level0_col14" class="col_heading level0 col14" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster_5</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f870_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f870_row0_col0" class="data row0 col0" >0.675971</td>
#       <td id="T_0f870_row0_col1" class="data row0 col1" >0.498786</td>
#       <td id="T_0f870_row0_col2" class="data row0 col2" >0.379045</td>
#       <td id="T_0f870_row0_col3" class="data row0 col3" >0.122168</td>
#       <td id="T_0f870_row0_col4" class="data row0 col4" >0.287217</td>
#       <td id="T_0f870_row0_col5" class="data row0 col5" >0.480583</td>
#       <td id="T_0f870_row0_col6" class="data row0 col6" >0.232201</td>
#       <td id="T_0f870_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_0f870_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_0f870_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_0f870_row0_col10" class="data row0 col10" >0.375000</td>
#       <td id="T_0f870_row0_col11" class="data row0 col11" >0.587379</td>
#       <td id="T_0f870_row0_col12" class="data row0 col12" >0.037621</td>
#       <td id="T_0f870_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_0f870_row0_col14" class="data row0 col14" >2472</td>
#     </tr>
#     <tr>
#       <th id="T_0f870_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f870_row1_col0" class="data row1 col0" >0.629147</td>
#       <td id="T_0f870_row1_col1" class="data row1 col1" >0.802725</td>
#       <td id="T_0f870_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_0f870_row1_col3" class="data row1 col3" >0.197275</td>
#       <td id="T_0f870_row1_col4" class="data row1 col4" >0.263033</td>
#       <td id="T_0f870_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_0f870_row1_col6" class="data row1 col6" >0.736967</td>
#       <td id="T_0f870_row1_col7" class="data row1 col7" >0.114929</td>
#       <td id="T_0f870_row1_col8" class="data row1 col8" >0.154621</td>
#       <td id="T_0f870_row1_col9" class="data row1 col9" >0.730450</td>
#       <td id="T_0f870_row1_col10" class="data row1 col10" >0.039692</td>
#       <td id="T_0f870_row1_col11" class="dat

# %%
cols = list(df_joined_scaled_4.columns)
cols.remove("cluster_4")
# Calcular las medias para cada cluster
pt = pd.pivot_table(df_joined_scaled_4, index='cluster_4', values=cols, aggfunc='mean')

# Calcular la cantidad de elementos en cada cluster
add = pd.pivot_table(df_joined_scaled_4, index='cluster_4', values='genero_v', aggfunc='count')
pt['count'] = add

# Añadir 'count' a la lista de columnas para la visualización final
cols.append('count')

# Mostrar la tabla con estilos y gradientes de color
pt[cols].style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c5c21_row0_col0, #T_c5c21_row0_col5, #T_c5c21_row0_col7, #T_c5c21_row0_col11, #T_c5c21_row1_col1, #T_c5c21_row1_col4, #T_c5c21_row1_col8, #T_c5c21_row1_col10, #T_c5c21_row2_col2, #T_c5c21_row2_col13, #T_c5c21_row3_col3, #T_c5c21_row3_col6, #T_c5c21_row3_col9, #T_c5c21_row3_col12, #T_c5c21_row3_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c5c21_row0_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_c5c21_row0_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_c5c21_row0_col3 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_c5c21_row0_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_c5c21_row0_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_c5c21_row0_col8, #T_c5c21_row0_col9, #T_c5c21_row0_col12, #T_c5c21_row0_col13, #T_c5c21_row1_col2, #T_c5c21_row1_col5, #T_c5c21_row1_col6, #T_c5c21_row1_col14, #T_c5c21_row2_col1, #T_c5c21_row2_col3, #T_c5c21_row3_col0, #T_c5c21_row3_col2, #T_c5c21_row3_col4, #T_c5c21_row3_col7, #T_c5c21_row3_col10, #T_c5c21_row3_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c5c21_row0_col10 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_c5c21_row0_col14 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_c5c21_row1_col0, #T_c5c21_row2_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c5c21_row1_col3 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_c5c21_row1_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c5c21_row1_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c5c21_row1_col11 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c5c21_row1_col12 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c5c21_row1_col13 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_c5c21_row2_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c5c21_row2_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_c5c21_row2_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_c5c21_row2_col6 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_c5c21_row2_col8 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_c5c21_row2_col9 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_c5c21_row2_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_c5c21_row2_col11 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c5c21_row2_col12 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_c5c21_row2_col14 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_c5c21_row3_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_c5c21_row3_col5 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_c5c21_row3_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_c5c21_row3_col13 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c5c21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5c21_level0_col0" class="col_heading level0 col0" >genero_v</th>
#       <th id="T_c5c21_level0_col1" class="col_heading level0 col1" >categoria_probabilidad_Media</th>
#       <th id="T_c5c21_level0_col2" class="col_heading level0 col2" >categoria_probabilidad_Alta</th>
#       <th id="T_c5c21_level0_col3" class="col_heading level0 col3" >categoria_probabilidad_ Muy Alta</th>
#       <th id="T_c5c21_level0_col4" class="col_heading level0 col4" >age_category_Jovenes/Adultos</th>
#       <th id="T_c5c21_level0_col5" class="col_heading level0 col5" >age_category_Adultos</th>
#       <th id="T_c5c21_level0_col6" class="col_heading level0 col6" >age_category_Senior</th>
#       <th id="T_c5c21_level0_col7" class="col_heading level0 col7" >salary_segment_Salario bajo</th>
#       <th id="T_c5c21_level0_col8" class="col_heading level0 col8" >salary_segment_Salario medio</th>
#       <th id="T_c5c21_level0_col9" class="col_heading level0 col9" >salary_segment_Salario alto</th>
#       <th id="T_c5c21_level0_col10" class="col_heading level0 col10" >city_size_Ciudad pequeña</th>
#       <th id="T_c5c21_level0_col11" class="col_heading level0 col11" >city_size_Ciudad Media</th>
#       <th id="T_c5c21_level0_col12" class="col_heading level0 col12" >city_size_Gran ciudad</th>
#       <th id="T_c5c21_level0_col13" class="col_heading level0 col13" >cluster_6</th>
#       <th id="T_c5c21_level0_col14" class="col_heading level0 col14" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster_4</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5c21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5c21_row0_col0" class="data row0 col0" >0.675971</td>
#       <td id="T_c5c21_row0_col1" class="data row0 col1" >0.498786</td>
#       <td id="T_c5c21_row0_col2" class="data row0 col2" >0.379045</td>
#       <td id="T_c5c21_row0_col3" class="data row0 col3" >0.122168</td>
#       <td id="T_c5c21_row0_col4" class="data row0 col4" >0.287217</td>
#       <td id="T_c5c21_row0_col5" class="data row0 col5" >0.480583</td>
#       <td id="T_c5c21_row0_col6" class="data row0 col6" >0.232201</td>
#       <td id="T_c5c21_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_c5c21_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_c5c21_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_c5c21_row0_col10" class="data row0 col10" >0.375000</td>
#       <td id="T_c5c21_row0_col11" class="data row0 col11" >0.587379</td>
#       <td id="T_c5c21_row0_col12" class="data row0 col12" >0.037621</td>
#       <td id="T_c5c21_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_c5c21_row0_col14" class="data row0 col14" >2472</td>
#     </tr>
#     <tr>
#       <th id="T_c5c21_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5c21_row1_col0" class="data row1 col0" >0.643085</td>
#       <td id="T_c5c21_row1_col1" class="data row1 col1" >0.864362</td>
#       <td id="T_c5c21_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_c5c21_row1_col3" class="data row1 col3" >0.135638</td>
#       <td id="T_c5c21_row1_col4" class="data row1 col4" >0.643085</td>
#       <td id="T_c5c21_row1_col5" class="data row1 col5" >0.202128</td>
#       <td id="T_c5c21_row1_col6" class="data row1 col6" >0.154787</td>
#       <td id="T_c5c21_row1_col7" class="data row1 col7" >0.231915</td>
#       <td id="T_c5c21_row1_col8" class="data row1 col8" >0.676064</td>
#       <td id="T_c5c21_row1_col9" class="data row1 col9" >0.092021</td>
#       <td id="T_c5c21_row1_col10" class="data row1 col10" >0.453723</td>
#       <td id="T_c5c21_row1_col11" class="data row1 col11" >0.291489</td>
#       <td id="T_c5c21_row1_col12" class="data row1 col12" >0.254787</td>
#       <td id="T_c5c21_row1_col13" class="data row1 col13" >1.000000</td>
#       <td id="T_c5c21_row1_col14" class="data row1 col14" >1880</td>
#     </tr>
#     <tr>
#       <th id="T_c5c21_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c5c21_row2_col0" class="data row2 col0" >0.646729</td>
#       <td id="T_c5c21_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_c5c21_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c5c21_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_c5c21_row2_col4" class="data row2 col4" >0.333084</td>
#       <td id="T_c5c21_row2_col5" class="data row2 col5" >0.371589</td>
#       <td id="T_c5c21_row2_col6" class="data row2 col6" >0.295327</td>
#       <td id="T_c5c21_row2_col7" class="data row2 col7" >0.166355</td>

# %%
df_joined_scaled_6
# Out:
#          genero_v  categoria_probabilidad_Media  categoria_probabilidad_Alta  \
# pk_cid
# 1200307         1                             0                            0
# 330599          0                             0                            0
# 1136531         0                             0                            0
# 1138692         1                             0                            0
# 1258071         1                             0                            0
# ...           ...                           ...                          ...
# 1108774         0                             1                            0
# 1298291         1                             1                            0
# 1209693         0                             1                            0
# 1120992         0                             1                            0
# 1165902         0                             1                            0
#
#          categoria_probabilidad_ Muy Alta  age_category_Jovenes/Adultos  \
# pk_cid
# 1200307                                 1                             0
# 330599                                  1                             0
# 1136531                                 1                             0
# 1138692                                 1                             0
# 1258071                                 1                             0
# ...                                   ...                           ...
# 1108774                                 0                             1
# 1298291                                 0                             0
# 1209693                                 0                             1
# 1120992                                 0                             0
# 1165902                                 0                             0
#
#          age_category_Adultos  age_category_Senior  \
# pk_cid
# 1200307                     0                    1
# 330599                      0                    1
# 1136531                     1                    0
# 1138692                     0                    1
# 1258071                     0                    1
# ...                       ...                  ...
# 1108774                     0                    0
# 1298291                     0                    1
# 1209693                     0                    0
# 1120992                     1                    0
# 1165902                     1                    0
#
#          salary_segment_Salario bajo  salary_segment_Salario medio  \
# pk_cid
# 1200307                            0                             0
# 330599                             0                             0
# 1136531                            0                             0
# 1138692                            0                             0
# 1258071                            0                             0
# ...                              ...                           ...
# 1108774                            0                             0
# 1298291                            0                             1
# 1209693                            1                             0
# 1120992                            0                             0
# 1165902                            0                             0
#
#          salary_segment_Salario alto  city_size_Ciudad pequeña  \
# pk_cid
# 1200307                            1                         0
# 330599                             1                         0
# 1136531                            1                         0
# 1138692                            1                         0
# 1258071                            1                         0
# ...                              ...                       ...
# 1108774                            1                         0
# 1298291                            0                         0
# 1209693                            0                         0
# 1120992                            1                         0
# 1165902                            1                         0
#
#          city_size_Ciudad Media  city_size_Gran ciudad  cluster_4  cluster_6
# pk_cid
# 1200307                       0                      1          3          3
# 330599                        0                      1          3          3
# 1136531                       0                      1          3          4
# 1138692                       0                      1          3          3
# 1258071                       0                      1          3          3
# ...                         ...                    ...        ...        ...
# 1108774                       1                      0          1          1
# 1298291                       1                      0          1          1
# 1209693                       1                      0          0          0
# 1120992                       0                      1          3          4
# 1165902                       0                      1          3          4
#
# [10000 rows x 15 columns]

# %%
cols = list(df_joined_scaled_6.columns)
cols.remove("cluster_6")
# Calcular las medias para cada cluster
pt = pd.pivot_table(df_joined_scaled_6, index='cluster_6', values=cols, aggfunc='mean')

# Calcular la cantidad de elementos en cada cluster
add = pd.pivot_table(df_joined_scaled_6, index='cluster_6', values='genero_v', aggfunc='count')
pt['count'] = add

# Añadir 'count' a la lista de columnas para la visualización final
cols.append('count')

# Mostrar la tabla con estilos y gradientes de color
pt[cols].style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_20f10_row0_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_20f10_row0_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_20f10_row0_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_20f10_row0_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_20f10_row0_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_20f10_row0_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_20f10_row0_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_20f10_row0_col7, #T_20f10_row0_col11, #T_20f10_row0_col14, #T_20f10_row1_col1, #T_20f10_row1_col4, #T_20f10_row1_col10, #T_20f10_row2_col0, #T_20f10_row2_col2, #T_20f10_row2_col8, #T_20f10_row3_col3, #T_20f10_row3_col6, #T_20f10_row3_col9, #T_20f10_row3_col12, #T_20f10_row3_col13, #T_20f10_row4_col5, #T_20f10_row4_col13, #T_20f10_row5_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_20f10_row0_col8, #T_20f10_row0_col9, #T_20f10_row0_col12, #T_20f10_row0_col13, #T_20f10_row1_col2, #T_20f10_row2_col1, #T_20f10_row2_col3, #T_20f10_row2_col7, #T_20f10_row2_col9, #T_20f10_row2_col14, #T_20f10_row3_col2, #T_20f10_row3_col5, #T_20f10_row3_col10, #T_20f10_row3_col11, #T_20f10_row4_col2, #T_20f10_row4_col4, #T_20f10_row4_col6, #T_20f10_row4_col11, #T_20f10_row5_col0, #T_20f10_row5_col1, #T_20f10_row5_col3, #T_20f10_row5_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_20f10_row0_col10 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_20f10_row1_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_20f10_row1_col3 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_20f10_row1_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_20f10_row1_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_20f10_row1_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_20f10_row1_col8 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_20f10_row1_col9 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_20f10_row1_col11 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_20f10_row1_col12 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_20f10_row1_col13 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_20f10_row1_col14 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_20f10_row2_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_20f10_row2_col5, #T_20f10_row3_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_20f10_row2_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_20f10_row2_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_20f10_row2_col11 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_20f10_row2_col12 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_20f10_row2_col13, #T_20f10_row5_col13 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_20f10_row3_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_20f10_row3_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_20f10_row3_col7 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_20f10_row3_col8 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_20f10_row3_col14 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_20f10_row4_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_20f10_row4_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_20f10_row4_col3 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_20f10_row4_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_20f10_row4_col8 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_20f10_row4_col9 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_20f10_row4_col10 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_20f10_row4_col12 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_20f10_row4_col14 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_20f10_row5_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_20f10_row5_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_20f10_row5_col6 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_20f10_row5_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_20f10_row5_col9 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_20f10_row5_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_20f10_row5_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_20f10_row5_col12 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_20f10_row5_col14 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# </style>
# <table id="T_20f10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20f10_level0_col0" class="col_heading level0 col0" >genero_v</th>
#       <th id="T_20f10_level0_col1" class="col_heading level0 col1" >categoria_probabilidad_Media</th>
#       <th id="T_20f10_level0_col2" class="col_heading level0 col2" >categoria_probabilidad_Alta</th>
#       <th id="T_20f10_level0_col3" class="col_heading level0 col3" >categoria_probabilidad_ Muy Alta</th>
#       <th id="T_20f10_level0_col4" class="col_heading level0 col4" >age_category_Jovenes/Adultos</th>
#       <th id="T_20f10_level0_col5" class="col_heading level0 col5" >age_category_Adultos</th>
#       <th id="T_20f10_level0_col6" class="col_heading level0 col6" >age_category_Senior</th>
#       <th id="T_20f10_level0_col7" class="col_heading level0 col7" >salary_segment_Salario bajo</th>
#       <th id="T_20f10_level0_col8" class="col_heading level0 col8" >salary_segment_Salario medio</th>
#       <th id="T_20f10_level0_col9" class="col_heading level0 col9" >salary_segment_Salario alto</th>
#       <th id="T_20f10_level0_col10" class="col_heading level0 col10" >city_size_Ciudad pequeña</th>
#       <th id="T_20f10_level0_col11" class="col_heading level0 col11" >city_size_Ciudad Media</th>
#       <th id="T_20f10_level0_col12" class="col_heading level0 col12" >city_size_Gran ciudad</th>
#       <th id="T_20f10_level0_col13" class="col_heading level0 col13" >cluster_4</th>
#       <th id="T_20f10_level0_col14" class="col_heading level0 col14" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster_6</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20f10_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20f10_row0_col0" class="data row0 col0" >0.675971</td>
#       <td id="T_20f10_row0_col1" class="data row0 col1" >0.498786</td>
#       <td id="T_20f10_row0_col2" class="data row0 col2" >0.379045</td>
#       <td id="T_20f10_row0_col3" class="data row0 col3" >0.122168</td>
#       <td id="T_20f10_row0_col4" class="data row0 col4" >0.287217</td>
#       <td id="T_20f10_row0_col5" class="data row0 col5" >0.480583</td>
#       <td id="T_20f10_row0_col6" class="data row0 col6" >0.232201</td>
#       <td id="T_20f10_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_20f10_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_20f10_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_20f10_row0_col10" class="data row0 col10" >0.375000</td>
#       <td id="T_20f10_row0_col11" class="data row0 col11" >0.587379</td>
#       <td id="T_20f10_row0_col12" class="data row0 col12" >0.037621</td>
#       <td id="T_20f10_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_20f10_row0_col14" class="data row0 col14" >2472</td>
#     </tr>
#     <tr>
#       <th id="T_20f10_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20f10_row1_col0" class="data row1 col0" >0.643085</td>

# %%
df_joined_scaled_5
# Out:
#          genero_v  categoria_probabilidad_Media  categoria_probabilidad_Alta  \
# pk_cid
# 1200307         1                             0                            0
# 330599          0                             0                            0
# 1136531         0                             0                            0
# 1138692         1                             0                            0
# 1258071         1                             0                            0
# ...           ...                           ...                          ...
# 1108774         0                             1                            0
# 1298291         1                             1                            0
# 1209693         0                             1                            0
# 1120992         0                             1                            0
# 1165902         0                             1                            0
#
#          categoria_probabilidad_ Muy Alta  age_category_Jovenes/Adultos  \
# pk_cid
# 1200307                                 1                             0
# 330599                                  1                             0
# 1136531                                 1                             0
# 1138692                                 1                             0
# 1258071                                 1                             0
# ...                                   ...                           ...
# 1108774                                 0                             1
# 1298291                                 0                             0
# 1209693                                 0                             1
# 1120992                                 0                             0
# 1165902                                 0                             0
#
#          age_category_Adultos  age_category_Senior  \
# pk_cid
# 1200307                     0                    1
# 330599                      0                    1
# 1136531                     1                    0
# 1138692                     0                    1
# 1258071                     0                    1
# ...                       ...                  ...
# 1108774                     0                    0
# 1298291                     0                    1
# 1209693                     0                    0
# 1120992                     1                    0
# 1165902                     1                    0
#
#          salary_segment_Salario bajo  salary_segment_Salario medio  \
# pk_cid
# 1200307                            0                             0
# 330599                             0                             0
# 1136531                            0                             0
# 1138692                            0                             0
# 1258071                            0                             0
# ...                              ...                           ...
# 1108774                            0                             0
# 1298291                            0                             1
# 1209693                            1                             0
# 1120992                            0                             0
# 1165902                            0                             0
#
#          salary_segment_Salario alto  city_size_Ciudad pequeña  \
# pk_cid
# 1200307                            1                         0
# 330599                             1                         0
# 1136531                            1                         0
# 1138692                            1                         0
# 1258071                            1                         0
# ...                              ...                       ...
# 1108774                            1                         0
# 1298291                            0                         0
# 1209693                            0                         0
# 1120992                            1                         0
# 1165902                            1                         0
#
#          city_size_Ciudad Media  city_size_Gran ciudad  cluster_5  cluster_6
# pk_cid
# 1200307                       0                      1          1          3
# 330599                        0                      1          1          3
# 1136531                       0                      1          4          4
# 1138692                       0                      1          1          3
# 1258071                       0                      1          1          3
# ...                         ...                    ...        ...        ...
# 1108774                       1                      0          3          1
# 1298291                       1                      0          3          1
# 1209693                       1                      0          0          0
# 1120992                       0                      1          4          4
# 1165902                       0                      1          4          4
#
# [10000 rows x 15 columns]

# %%
# Guardar la columna de clusters
clusters_5 = df_joined_scaled_5['cluster_5']

# Eliminar el resto de las columnas escaladas
df_joined_scaled_5.drop(columns=df_joined_scaled_5.columns, inplace=True)

# Revertir a los datos originales (sin escalar), salvo por la columna de clusters
df_joined_scaled_5 = df_joined.copy()

# Añadir la columna de clusters al DataFrame original
df_joined_scaled_5['cluster_5'] = clusters_5

# %%
df_joined_scaled_5
# Out:
#          genero_v  categoria_probabilidad_Media  categoria_probabilidad_Alta  \
# pk_cid
# 1200307         1                             0                            0
# 330599          0                             0                            0
# 1136531         0                             0                            0
# 1138692         1                             0                            0
# 1258071         1                             0                            0
# ...           ...                           ...                          ...
# 1108774         0                             1                            0
# 1298291         1                             1                            0
# 1209693         0                             1                            0
# 1120992         0                             1                            0
# 1165902         0                             1                            0
#
#          categoria_probabilidad_ Muy Alta  age_category_Jovenes/Adultos  \
# pk_cid
# 1200307                                 1                             0
# 330599                                  1                             0
# 1136531                                 1                             0
# 1138692                                 1                             0
# 1258071                                 1                             0
# ...                                   ...                           ...
# 1108774                                 0                             1
# 1298291                                 0                             0
# 1209693                                 0                             1
# 1120992                                 0                             0
# 1165902                                 0                             0
#
#          age_category_Adultos  age_category_Senior  \
# pk_cid
# 1200307                     0                    1
# 330599                      0                    1
# 1136531                     1                    0
# 1138692                     0                    1
# 1258071                     0                    1
# ...                       ...                  ...
# 1108774                     0                    0
# 1298291                     0                    1
# 1209693                     0                    0
# 1120992                     1                    0
# 1165902                     1                    0
#
#          salary_segment_Salario bajo  salary_segment_Salario medio  \
# pk_cid
# 1200307                            0                             0
# 330599                             0                             0
# 1136531                            0                             0
# 1138692                            0                             0
# 1258071                            0                             0
# ...                              ...                           ...
# 1108774                            0                             0
# 1298291                            0                             1
# 1209693                            1                             0
# 1120992                            0                             0
# 1165902                            0                             0
#
#          salary_segment_Salario alto  city_size_Ciudad pequeña  \
# pk_cid
# 1200307                            1                         0
# 330599                             1                         0
# 1136531                            1                         0
# 1138692                            1                         0
# 1258071                            1                         0
# ...                              ...                       ...
# 1108774                            1                         0
# 1298291                            0                         0
# 1209693                            0                         0
# 1120992                            1                         0
# 1165902                            1                         0
#
#          city_size_Ciudad Media  city_size_Gran ciudad  cluster_4  cluster_5  \
# pk_cid
# 1200307                       0                      1          3          1
# 330599                        0                      1          3          1
# 1136531                       0                      1          3          4
# 1138692                       0                      1          3          1
# 1258071                       0                      1          3          1
# ...                         ...                    ...        ...        ...
# 1108774                       1                      0          1          3
# 1298291                       1                      0          1          3
# 1209693                       1                      0          0          0
# 1120992                       0                      1          3          4
# 1165902                       0                      1          3          4
#
#          cluster_6
# pk_cid
# 1200307          3
# 330599           3
# 1136531          4
# 1138692          3
# 1258071          3
# ...            ...
# 1108774          1
# 1298291          1
# 1209693          0
# 1120992          4
# 1165902          4
#
# [10000 rows x 16 columns]

# %%
# Calcular las medias de todas las columnas agrupadas por el cluster
cluster_means = df_joined_scaled_5.groupby('cluster_5').mean()

# Mostrar las medias
cluster_means
# Out:
#            genero_v  categoria_probabilidad_Media  \
# cluster_5
# 0             0.676                         0.499
# 1             0.629                         0.803
# 2             0.647                         0.000
# 3             0.643                         0.864
# 4             0.659                         0.823
#
#            categoria_probabilidad_Alta  categoria_probabilidad_ Muy Alta  \
# cluster_5
# 0                                0.379                             0.122
# 1                                0.000                             0.197
# 2                                1.000                             0.000
# 3                                0.000                             0.136
# 4                                0.000                             0.177
#
#            age_category_Jovenes/Adultos  age_category_Adultos  \
# cluster_5
# 0                                 0.287                 0.481
# 1                                 0.263                 0.000
# 2                                 0.333                 0.372
# 3                                 0.643                 0.202
# 4                                 0.000                 1.000
#
#            age_category_Senior  salary_segment_Salario bajo  \
# cluster_5
# 0                        0.232                        1.000
# 1                        0.737                        0.115
# 2                        0.295                        0.166
# 3                        0.155                        0.232
# 4                        0.000                        0.177
#
#            salary_segment_Salario medio  salary_segment_Salario alto  \
# cluster_5
# 0                                 0.000                        0.000
# 1                                 0.155                        0.730
# 2                                 0.419                        0.415
# 3                                 0.676                        0.092
# 4                                 0.318                        0.505
#
#            city_size_Ciudad pequeña  city_size_Ciudad Media  \
# cluster_5
# 0                             0.375                   0.587
# 1                             0.040                   0.059
# 2                             0.146                   0.164
# 3                             0.454                   0.291
# 4                             0.052                   0.060
#
#            city_size_Gran ciudad  cluster_4  cluster_6
# cluster_5
# 0                          0.038      0.000      0.000
# 1                          0.901      3.000      3.000
# 2                          0.690      2.000      3.743
# 3                          0.255      1.000      1.000
# 4                          0.888      3.000      4.000

# %%
# Guardar la columna de clusters
clusters_4 = df_joined_scaled_4['cluster_4']

# Eliminar el resto de las columnas escaladas
df_joined_scaled_4.drop(columns=df_joined_scaled_4.columns, inplace=True)

# Revertir a los datos originales (sin escalar), salvo por la columna de clusters
df_joined_scaled_4 = df_joined.copy()

# Añadir la columna de clusters al DataFrame original
df_joined_scaled_4['cluster_4'] = clusters_4

# %%
# Calcular las medias de todas las columnas agrupadas por el cluster
cluster_means = df_joined_scaled_4.groupby('cluster_4').mean()

# Mostrar las medias
cluster_means
# Out:
#            genero_v  categoria_probabilidad_Media  \
# cluster_4
# 0             0.676                         0.499
# 1             0.643                         0.864
# 2             0.647                         0.000
# 3             0.642                         0.811
#
#            categoria_probabilidad_Alta  categoria_probabilidad_ Muy Alta  \
# cluster_4
# 0                                0.379                             0.122
# 1                                0.000                             0.136
# 2                                1.000                             0.000
# 3                                0.000                             0.189
#
#            age_category_Jovenes/Adultos  age_category_Adultos  \
# cluster_4
# 0                                 0.287                 0.481
# 1                                 0.643                 0.202
# 2                                 0.333                 0.372
# 3                                 0.149                 0.432
#
#            age_category_Senior  salary_segment_Salario bajo  \
# cluster_4
# 0                        0.232                        1.000
# 1                        0.155                        0.232
# 2                        0.295                        0.166
# 3                        0.418                        0.142
#
#            salary_segment_Salario medio  salary_segment_Salario alto  \
# cluster_4
# 0                                 0.000                        0.000
# 1                                 0.676                        0.092
# 2                                 0.419                        0.415
# 3                                 0.225                        0.633
#
#            city_size_Ciudad pequeña  city_size_Ciudad Media  \
# cluster_4
# 0                             0.375                   0.587
# 1                             0.454                   0.291
# 2                             0.146                   0.164
# 3                             0.045                   0.060
#
#            city_size_Gran ciudad  cluster_5  cluster_6
# cluster_4
# 0                          0.038      0.000      0.000
# 1                          0.255      3.000      1.000
# 2                          0.690      2.000      3.743
# 3                          0.895      2.297      3.432

# %%
# Guardar la columna de clusters
clusters_6 = df_joined_scaled_6['cluster_6']

# Eliminar el resto de las columnas escaladas
df_joined_scaled_6.drop(columns=df_joined_scaled_6.columns, inplace=True)

# Revertir a los datos originales (sin escalar), salvo por la columna de clusters
df_joined_scaled_6 = df_joined.copy()

# Añadir la columna de clusters al DataFrame original
df_joined_scaled_6['cluster_6'] = clusters_6

# %%
# Calcular las medias de todas las columnas agrupadas por el cluster
cluster_means = df_joined_scaled_6.groupby('cluster_6').mean()

# Mostrar las medias
cluster_means
# Out:
#            genero_v  categoria_probabilidad_Media  \
# cluster_6
# 0             0.676                         0.499
# 1             0.643                         0.864
# 2             0.686                         0.000
# 3             0.629                         0.803
# 4             0.659                         0.823
# 5             0.618                         0.000
#
#            categoria_probabilidad_Alta  categoria_probabilidad_ Muy Alta  \
# cluster_6
# 0                                0.379                             0.122
# 1                                0.000                             0.136
# 2                                1.000                             0.000
# 3                                0.000                             0.197
# 4                                0.000                             0.177
# 5                                1.000                             0.000
#
#            age_category_Jovenes/Adultos  age_category_Adultos  \
# cluster_6
# 0                                 0.287                 0.481
# 1                                 0.643                 0.202
# 2                                 0.326                 0.409
# 3                                 0.263                 0.000
# 4                                 0.000                 1.000
# 5                                 0.338                 0.344
#
#            age_category_Senior  salary_segment_Salario bajo  \
# cluster_6
# 0                        0.232                        1.000
# 1                        0.155                        0.232
# 2                        0.265                        0.000
# 3                        0.737                        0.115
# 4                        0.000                        0.177
# 5                        0.317                        0.286
#
#            salary_segment_Salario medio  salary_segment_Salario alto  \
# cluster_6
# 0                                 0.000                        0.000
# 1                                 0.676                        0.092
# 2                                 1.000                        0.000
# 3                                 0.155                        0.730
# 4                                 0.318                        0.505
# 5                                 0.000                        0.714
#
#            city_size_Ciudad pequeña  city_size_Ciudad Media  \
# cluster_6
# 0                             0.375                   0.587
# 1                             0.454                   0.291
# 2                             0.247                   0.240
# 3                             0.040                   0.059
# 4                             0.052                   0.060
# 5                             0.073                   0.109
#
#            city_size_Gran ciudad  cluster_4  cluster_5
# cluster_6
# 0                          0.038      0.000      0.000
# 1                          0.255      1.000      3.000
# 2                          0.513      2.000      2.000
# 3                          0.901      3.000      1.000
# 4                          0.888      3.000      4.000
# 5                          0.817      2.000      2.000

# %% [markdown]
# # Segmentos de Clientes y Estrategias de Marketing
#
# ## 1. Ahorristas de Ciudad Media
# **Características:**
# - **Género:** 68.5% masculino.
# - **Probabilidad de compra:** Media (32.2%).
# - **Edad:** Principalmente adultos (69.7% adultos).
# - **Salario:** Principalmente bajo (90.3%).
# - **Ubicación:** Mayormente en ciudades medianas (67.1%).
#
# **Idea para el Email:**
# - **Asunto:** “¡Maximiza tus ahorros con nuestra tarjeta de crédito!”
# - **Cuerpo:** Resaltar cómo la tarjeta de crédito ofrece recompensas en compras cotidianas y la posibilidad de acumular ahorros. Proporcionar ejemplos de cómo ahorrar en gastos esenciales puede llevar a grandes beneficios.
# - **Descripción de la imagen:** Una imagen de un hombre o una mujer (adulto joven) mirando con satisfacción su aplicación de finanzas personales en un smartphone, rodeado de elementos que simbolizan ahorro (como una alcancía o cupones).
#
# ---
#
# ## 2. Inversores de Grandes Ciudades
# **Características:**
# - **Género:** 62.9% masculino.
# - **Probabilidad de compra:** Alta (74.0%).
# - **Edad:** En su mayoría adultos (60.4% adultos).
# - **Salario:** Mayormente alto (80.1%).
# - **Ubicación:** Predominantemente en grandes ciudades (85.6%).
#
# **Idea para el Email:**
# - **Asunto:** “¡Impulsa tu inversión con nuestra tarjeta premium!”
# - **Cuerpo:** Enfatizar los beneficios de la tarjeta, como cashback en inversiones, acceso a productos financieros exclusivos, y cómo puede ayudarles a alcanzar sus objetivos financieros.
# - **Descripción de la imagen:** Una imagen que muestre a un adulto usando su tarjeta de crédito en un entorno moderno de oficina, con gráficos financieros en segundo plano y una expresión de confianza en su rostro.
#
# ---
#
# ## 3. Viajeros Jóvenes de Ciudades Grandes
# **Características:**
# - **Género:** 63.8% masculino.
# - **Probabilidad de compra:** Muy alta (81.4%).
# - **Edad:** Jóvenes (68.0% jóvenes).
# - **Salario:** Salario medio (36.9%).
# - **Ubicación:** Con una buena mezcla en grandes ciudades (71.9%).
#
# **Idea para el Email:**
# - **Asunto:** “¡Viaja más y gasta menos con nuestra tarjeta de crédito!”
# - **Cuerpo:** Mostrar cómo la tarjeta de crédito ofrece puntos o recompensas en viajes y descuentos en hoteles, y cómo puede hacer que sus experiencias de viaje sean más accesibles.
# - **Descripción de la imagen:** Una imagen de un grupo de amigos disfrutando de un viaje, usando su tarjeta de crédito en un restaurante exótico, con una vista espectacular de fondo.
#
# ---
#
# ## 4. Profesionales de Ciudades Medias
# **Características:**
# - **Género:** 64.7% masculino.
# - **Probabilidad de compra:** Media (61.5%).
# - **Edad:** Principalmente adultos (74.4% adultos).
# - **Salario:** Principalmente medio (100%).
# - **Ubicación:** Principalmente en ciudades medianas (22.5%).
#
# **Idea para el Email:**
# - **Asunto:** “¡Tu confianza merece una tarjeta que te respalde!”
# - **Cuerpo:** Resaltar la seguridad y confiabilidad de la tarjeta, sus beneficios en emergencias y su capacidad para ayudarles a manejar sus finanzas de manera efectiva.
# - **Descripción de la imagen:** Una imagen que muestre a un profesional revisando sus finanzas en un entorno de trabajo, con un enfoque en su tarjeta de crédito en la mesa, simbolizando la confianza y la seguridad.
#
# ---
#
# ## 5. Compradores Urbanos Diversos
# **Características:**
# - **Género:** 66.1% masculino.
# - **Probabilidad de compra:** Alta (96.9%).
# - **Edad:** Mezcla de adultos y seniors (59.1% adultos, 12.6% seniors).
# - **Salario:** Principalmente bajo (54.8%).
# - **Ubicación:** Ubicados en grandes ciudades (100%).
#
# **Idea para el Email:**
# - **Asunto:** “¡Revoluciona tu forma de comprar con nuestra tarjeta de crédito!”
# - **Cuerpo:** Resaltar los descuentos y ofertas exclusivas que pueden obtener al utilizar la tarjeta en compras diarias, así como la facilidad de pago.
# - **Descripción de la imagen:** Una imagen vibrante de una mujer joven y un hombre mayor en un centro comercial, ambos felices mientras utilizan su tarjeta de crédito en la caja, mostrando la satisfacción de comprar.
